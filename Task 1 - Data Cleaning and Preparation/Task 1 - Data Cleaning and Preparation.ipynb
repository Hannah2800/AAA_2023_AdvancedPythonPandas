# %%
# import all necessary packages
import pandas as pd
import numpy as np
#import json
import datetime
#import seaborn as sns
#import matplotlib as mlp
import matplotlib.pyplot as plt

#from haversine import haversine
#from datetime import datetime

# %% [markdown]
# # 1.1 Taxi data

# %%
# import datasets: every month individually

df_jan = pd.read_csv("../data/taxi/Taxi_Trips-1.csv")
df_feb = pd.read_csv("../data/taxi/Taxi_Trips-2.csv")
df_mar = pd.read_csv("../data/taxi/Taxi_Trips-3.csv")
df_apr = pd.read_csv("../data/taxi/Taxi_Trips-4.csv")
df_may = pd.read_csv("../data/taxi/Taxi_Trips-5.csv")
df_jun = pd.read_csv("../data/taxi/Taxi_Trips-6.csv")
df_jul = pd.read_csv("../data/taxi/Taxi_Trips-7.csv")
df_aug = pd.read_csv("../data/taxi/Taxi_Trips-8.csv")
df_sept = pd.read_csv("../data/taxi/Taxi_Trips-9.csv")
df_oct = pd.read_csv("../data/taxi/Taxi_Trips-10.csv")
df_nov = pd.read_csv("../data/taxi/Taxi_Trips-11.csv")
df_dec = pd.read_csv("../data/taxi/Taxi_Trips-12.csv")

# %%
# combining the dataframes to one (for the whole year)

df_chicago = pd.concat([df_jan,df_feb,df_mar,df_apr,df_may,df_jun,df_jul,df_aug,df_sept,
           df_oct,df_nov,df_dec], axis=0)

# %%
df_chicago = df_chicago.reset_index(drop = True)

# %%
df_chicago.columns = df_chicago.columns.str.strip().str.replace(' ','_')

# %%
# change type of Trip_Start_Timestamp and Trip_End_Timestamp to datetime object

df_chicago['Trip_Start_Timestamp'] = pd.to_datetime(df_chicago['Trip_Start_Timestamp'])
df_chicago['Trip_End_Timestamp'] = pd.to_datetime(df_chicago['Trip_End_Timestamp'])

# %%
df_chicago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27217716 entries, 0 to 27217715
# Data columns (total 24 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   Trip_ID                     object
#  1   Taxi_ID                     object
#  2   Trip_Start_Timestamp        datetime64[ns]
#  3   Trip_End_Timestamp          datetime64[ns]
#  4   Trip_Seconds                float64
#  5   Trip_Miles                  float64
#  6   Pickup_Census_Tract         float64
#  7   Dropoff_Census_Tract        float64
#  8   Pickup_Community_Area       float64
#  9   Dropoff_Community_Area      float64
#  10  Fare                        float64
#  11  Tips                        float64
#  12  Tolls                       float64
#  13  Extras                      float64
#  14  Trip_Total                  float64
#  15  Payment_Type                object
#  16  Company                     object
#  17  Pickup_Centroid_Latitude    float64
#  18  Pickup_Centroid_Longitude   float64
#  19  Pickup_Centroid_Location    object
#  20  Dropoff_Centroid_Latitude   float64
#  21  Dropoff_Centroid_Longitude  float64
#  22  Dropoff_Centroid__Location  object
#  23  Community_Areas             float64
# dtypes: datetime64[ns](2), float64(16), object(6)
# memory usage: 4.9+ GB

# %%
df_chicago.head()
# Out:
#                                     Trip_ID  \
# 0  eda829a425ca1da13e1130c700c876881e26ff9a
# 1  0c2b3705c9748a5949bf5b7d727b2d1f2e18805f
# 2  c15dc571c96c36e44bc4ed50f40330e9f0a21650
# 3  3c979de8d901f317228a40673c3923d72104b92c
# 4  27ad87f629bf14fa3cb894daad514cdad4736f9c
#
#                                              Taxi_ID Trip_Start_Timestamp  \
# 0  b47c583b142d75b42882975eaab19c6cb98d8268601657...           2013-01-01
# 1  c2280976049b22e58ce53a17263114616be76981b9ac56...           2013-01-01
# 2  294ae9e2f433bb460731f9199b1837de3cf88ad987a42b...           2013-01-01
# 3  2db2ec3555e44930a5d41596cb7935af41c30c30381672...           2013-01-01
# 4  4b38941e0745acdeefe630832a438a59fdaac78640f68a...           2013-01-01
#
#    Trip_End_Timestamp  Trip_Seconds  Trip_Miles  Pickup_Census_Tract  \
# 0 2013-01-01 00:15:00         600.0         3.0                  NaN
# 1 2013-01-01 00:30:00        1320.0        12.3                  NaN
# 2 2013-01-01 00:30:00        1320.0         6.3                  NaN
# 3 2013-01-01 01:30:00        5520.0        88.8         1.703106e+10
# 4 2013-01-01 00:15:00         900.0         2.7                  NaN
#
#    Dropoff_Census_Tract  Pickup_Community_Area  Dropoff_Community_Area  ...  \
# 0                   NaN                    NaN                     NaN  ...
# 1                   NaN                    NaN                     NaN  ...
# 2                   NaN                    NaN                     NaN  ...
# 3                   NaN                    6.0                     NaN  ...
# 4                   NaN                   28.0                     8.0  ...
#
#    Trip_Total  Payment_Type  Company  Pickup_Centroid_Latitude  \
# 0        9.65          Cash      NaN                       NaN
# 1       26.25          Cash      NaN                       NaN
# 2       19.45   Credit Card      NaN                       NaN
# 3      317.81   Credit Card      NaN                 41.942585
# 4       11.45          Cash      NaN                 41.874005
#
#    Pickup_Centroid_Longitude              Pickup_Centroid_Location  \
# 0                        NaN                                   NaN
# 1                        NaN                                   NaN
# 2                        NaN                                   NaN
# 3                 -87.656644  POINT (-87.6566440918 41.9425851797)
# 4                 -87.663518   POINT (-87.6635175498 41.874005383)
#
#   Dropoff_Centroid_Latitude  Dropoff_Centroid_Longitude  \
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                 41.899602                  -87.633308
#
#             Dropoff_Centroid__Location Community_Areas
# 0                                  NaN             NaN
# 1                                  NaN             NaN
# 2                                  NaN             NaN
# 3                                  NaN            57.0
# 4  POINT (-87.6333080367 41.899602111)            29.0
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Cleaning the dataframe: `df_chicago`

# %% [markdown]
# ### General:

# %%
print(f"Number of duplicated rows: {len(df_chicago)-len(df_chicago.drop_duplicates(keep=False))}")
# Out:
# Number of duplicated rows: 0

# %%
# check if there are duplicated Trip_ID's

print(f"Number of duplicated Trips ID's: {df_chicago.duplicated(subset=['Trip_ID']).sum()}")
# Out:
# Number of duplicated Trips ID's: 0

# %%
df_chicago.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27217716 entries, 0 to 27217715
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count     Dtype
# ---  ------                      --------------     -----
#  0   Trip_ID                     27217716 non-null  object
#  1   Taxi_ID                     27217300 non-null  object
#  2   Trip_Start_Timestamp        27217716 non-null  datetime64[ns]
#  3   Trip_End_Timestamp          27214283 non-null  datetime64[ns]
#  4   Trip_Seconds                26089923 non-null  float64
#  5   Trip_Miles                  27217508 non-null  float64
#  6   Pickup_Census_Tract         16420305 non-null  float64
#  7   Dropoff_Census_Tract        15995630 non-null  float64
#  8   Pickup_Community_Area       22565506 non-null  float64
#  9   Dropoff_Community_Area      21804491 non-null  float64
#  10  Fare                        27217445 non-null  float64
#  11  Tips                        27217445 non-null  float64
#  12  Tolls                       26870017 non-null  float64
#  13  Extras                      27217445 non-null  float64
#  14  Trip_Total                  27217445 non-null  float64
#  15  Payment_Type                27217716 non-null  object
#  16  Company                     17334977 non-null  object
#  17  Pickup_Centroid_Latitude    22566008 non-null  float64
#  18  Pickup_Centroid_Longitude   22566008 non-null  float64
#  19  Pickup_Centroid_Location    22566008 non-null  object
#  20  Dropoff_Centroid_Latitude   21836085 non-null  float64
#  21  Dropoff_Centroid_Longitude  21836085 non-null  float64
#  22  Dropoff_Centroid__Location  21836085 non-null  object
#  23  Community_Areas             22565981 non-null  float64
# dtypes: datetime64[ns](2), float64(16), object(6)
# memory usage: 4.9+ GB

# %% [markdown]
# Since we don't need the column `Company`for any of our tasks and there are a lot of null values in it, we drop this column:

# %%
df_chicago.drop(columns=['Company'],inplace=True)

# %% [markdown]
# ### Location based:

# %% [markdown]
# We drop the rows where either the `Pickup_Community_Area` or the `Dropoff_Community_Area` is null. These NaN values indicate a location outside of chicago. We don't need to do that with the `Pickup_Census_Trac` and `Dropoff_Census_Trac`, since if these columns are null, we have the community area (https://data.cityofchicago.org/Transportation/Taxi-Trips/wrvz-psew (see at: "Columns in these Dataset")).

# %%
df_chicago.dropna(subset=['Pickup_Community_Area', 'Dropoff_Community_Area'], inplace = True)

# %%
df_chicago = df_chicago.reset_index(drop = True)
df_chicago
# Out:
#                                            Trip_ID  \
# 0         27ad87f629bf14fa3cb894daad514cdad4736f9c
# 1         7a3c9ab6e4da5c35448753e981bb73065a0c0319
# 2         9a9d9902dfa267b88400a22a2c9f0cf74384b372
# 3         9b4be9a70a4d74427e00adac7d90f469e36bddc7
# 4         091eda4ec41520d6ba96003f05eb10744f73aa82
# ...                                            ...
# 21638627  a155865e7578ddd52ed77443c6fed7f981c694b1
# 21638628  35a5fe3a96ad453a9276112136c934a87379e8a5
# 21638629  f6fa0574a62cab2fec2c9ea2cc075f8ff6ee19e5
# 21638630  de95a68aae83de22d19a7999111f249e90eae812
# 21638631  2520e0373a96d517bfdebf51df22d1cefa0ac2c3
#
#                                                     Taxi_ID  \
# 0         4b38941e0745acdeefe630832a438a59fdaac78640f68a...
# 1         efce437d4bc2a79b12ac131e37789da8fe5e53f37d12c2...
# 2         1a1189d1e9f4f676bbeaf49903912684b94453576a234f...
# 3         a1b8eb24fa71867de525452474490e1c822269411962fe...
# 4         e6f3cad6dc920f7782dccd76a1e0f147fc8361af905b4b...
# ...                                                     ...
# 21638627  cc33cdc1816a9ba9822dd033062f8d414cac183bbfa7fc...
# 21638628  341cead8979074196f3231099ef811c4e905d7031dd6d7...
# 21638629  c01573d08b208b89c0fdf054d7bc2820fe2abb9d326a80...
# 21638630  5866e731fed5c82556c87a73b3ec2e19dd13d4cdc46a34...
# 21638631  c7475fec1fa338d525948b60cc20c8a47905a257c68ef8...
#
#          Trip_Start_Timestamp  Trip_End_Timestamp  Trip_Seconds  Trip_Miles  \
# 0         2013-01-01 00:00:00 2013-01-01 00:15:00         900.0         2.7
# 1         2013-01-01 00:00:00 2013-01-01 00:00:00          60.0         0.3
# 2         2013-01-01 00:00:00 2013-01-01 00:00:00         240.0         0.4
# 3         2013-01-01 00:00:00 2013-01-01 00:15:00         600.0         0.0
# 4         2013-01-01 00:00:00 2013-01-01 00:15:00         720.0         0.0
# ...                       ...                 ...           ...         ...
# 21638627  2013-12-31 23:45:00 2013-12-31 23:45:00         536.0         1.6
# 21638628  2013-12-31 23:45:00 2014-01-01 00:15:00        1952.0         8.5
# 21638629  2013-12-31 23:45:00 2013-12-31 23:45:00         262.0         0.9
# 21638630  2013-12-31 23:45:00 2013-12-31 23:45:00         352.0         0.7
# 21638631  2013-12-31 23:45:00 2014-01-01 00:00:00        1141.0         4.4
#
#           Pickup_Census_Tract  Dropoff_Census_Tract  Pickup_Community_Area  \
# 0                         NaN                   NaN                   28.0
# 1                1.703132e+10          1.703132e+10                   32.0
# 2                1.703107e+10          1.703107e+10                    7.0
# 3                1.703107e+10          1.703106e+10                    7.0
# 4                1.703108e+10          1.703103e+10                    8.0
# ...                       ...                   ...                    ...
# 21638627         1.703106e+10          1.703103e+10                    6.0
# 21638628                  NaN                   NaN                   28.0
# 21638629         1.703132e+10          1.703108e+10                   32.0
# 21638630         1.703106e+10          1.703106e+10                    6.0
# 21638631         1.703132e+10          1.703124e+10                   32.0
#
#           Dropoff_Community_Area  ...  Extras  Trip_Total  Payment_Type  \
# 0                            8.0  ...     1.0       11.45          Cash
# 1                           32.0  ...     0.0        3.85          Cash
# 2                            7.0  ...     0.0        4.84          Cash
# 3                            6.0  ...     0.0        7.25          Cash
# 4                            3.0  ...     0.0       15.25          Cash
# ...                          ...  ...     ...         ...           ...
# 21638627                     3.0  ...     0.0        9.85   Credit Card
# 21638628                     6.0  ...     2.0       23.45          Cash
# 21638629                     8.0  ...     2.0        7.25          Cash
# 21638630                     6.0  ...     0.0        7.05   Credit Card
# 21638631                    24.0  ...     1.5       14.55          Cash
#
#           Pickup_Centroid_Latitude  Pickup_Centroid_Longitude  \
# 0                        41.874005                 -87.663518
# 1                        41.870607                 -87.622173
# 2                        41.928967                 -87.656157
# 3                        41.929047                 -87.651311
# 4                        41.895033                 -87.619711
# ...                            ...                        ...
# 21638627                 41.941556                 -87.666289
# 21638628                 41.874005                 -87.663518
# 21638629                 41.884987                 -87.620993
# 21638630                 41.942577                 -87.647079
# 21638631                 41.884987                 -87.620993
#
#                       Pickup_Centroid_Location  Dropoff_Centroid_Latitude  \
# 0          POINT (-87.6635175498 41.874005383)                  41.899602
# 1         POINT (-87.6221729369 41.8706073724)                  41.870607
# 2         POINT (-87.6561568309 41.9289672664)                  41.929047
# 3         POINT (-87.6513108767 41.9290469366)                  41.942577
# 4         POINT (-87.6197106717 41.8950334495)                  41.972929
# ...                                        ...                        ...
# 21638627   POINT (-87.6662888874 41.941555829)                  41.965446
# 21638628   POINT (-87.6635175498 41.874005383)                  41.944227
# 21638629  POINT (-87.6209929134 41.8849871918)                  41.898332
# 21638630   POINT (-87.6470785093 41.942577185)                  41.934540
# 21638631  POINT (-87.6209929134 41.8849871918)                  41.912364
#
#           Dropoff_Centroid_Longitude  \
# 0                         -87.633308
# 1                         -87.622173
# 2                         -87.651311
# 3                         -87.647079
# 4                         -87.650290
# ...                              ...
# 21638627                  -87.663196
# 21638628                  -87.655998
# 21638629                  -87.620763
# 21638630                  -87.643023
# 21638631                  -87.675063
#
#                         Dropoff_Centroid__Location  Community_Areas
# 0              POINT (-87.6333080367 41.899602111)             29.0
# 1             POINT (-87.6221729369 41.8706073724)             38.0
# 2             POINT (-87.6513108767 41.9290469366)             68.0
# 3              POINT (-87.6470785093 41.942577185)             68.0
# 4             POINT (-87.6502900743 41.9729293173)             37.0
# ...                                            ...              ...
# 21638627      POINT (-87.6631958495 41.9654457842)             57.0
# 21638628      POINT (-87.6559981815 41.9442266014)             29.0
# 21638629      POINT (-87.6207628651 41.8983317935)             38.0
# 21638630  POINT (-87.6430228044 41.93453971580001)             57.0
# 21638631      POINT (-87.6750627566 41.9123643542)             38.0
#
# [21638632 rows x 23 columns]

# %%
#len(df_chicago['Pickup_Centroid_Location'])-len(df_chicago['Pickup_Centroid_Location'].dropna())

# %%
df_chicago.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21638632 entries, 0 to 21638631
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count     Dtype
# ---  ------                      --------------     -----
#  0   Trip_ID                     21638632 non-null  object
#  1   Taxi_ID                     21638259 non-null  object
#  2   Trip_Start_Timestamp        21638632 non-null  datetime64[ns]
#  3   Trip_End_Timestamp          21638632 non-null  datetime64[ns]
#  4   Trip_Seconds                21636858 non-null  float64
#  5   Trip_Miles                  21638437 non-null  float64
#  6   Pickup_Census_Tract         15863491 non-null  float64
#  7   Dropoff_Census_Tract        15863491 non-null  float64
#  8   Pickup_Community_Area       21638632 non-null  float64
#  9   Dropoff_Community_Area      21638632 non-null  float64
#  10  Fare                        21638396 non-null  float64
#  11  Tips                        21638396 non-null  float64
#  12  Tolls                       21304095 non-null  float64
#  13  Extras                      21638396 non-null  float64
#  14  Trip_Total                  21638396 non-null  float64
#  15  Payment_Type                21638632 non-null  object
#  16  Pickup_Centroid_Latitude    21638632 non-null  float64
#  17  Pickup_Centroid_Longitude   21638632 non-null  float64
#  18  Pickup_Centroid_Location    21638632 non-null  object
#  19  Dropoff_Centroid_Latitude   21638632 non-null  float64
#  20  Dropoff_Centroid_Longitude  21638632 non-null  float64
#  21  Dropoff_Centroid__Location  21638632 non-null  object
#  22  Community_Areas             21638607 non-null  float64
# dtypes: datetime64[ns](2), float64(16), object(5)
# memory usage: 3.7+ GB

# %% [markdown]
# ### `Trip_Miles` and `Trip_Seconds`:

# %%
print(f"Number of null values (NaN) in column 'Trip_Miles': {len(df_chicago['Trip_Miles'])-len(df_chicago['Trip_Miles'].dropna())}")
print(f"Number of null values (NaN) in column 'Trip_Seconds': {len(df_chicago['Trip_Seconds'])-len(df_chicago['Trip_Seconds'].dropna())}")
# Out:
# Number of null values (NaN) in column 'Trip_Miles': 195
# Number of null values (NaN) in column 'Trip_Seconds': 1774

# %%
df_chicago.dropna(subset=['Trip_Miles','Trip_Seconds'], inplace = True)

# %% [markdown]
# Below we check for trips which have negative or zero miles and trips which have a duration of less than a minute:

# %%
miles_ = (df_chicago['Trip_Miles'] <= 0).sum()
seconds_ = (df_chicago['Trip_Seconds'] < 60).sum()
print(miles_)
print(seconds_)
# Out:
# 9211247
# 689760

# %%
df_chicago = df_chicago[df_chicago['Trip_Miles'] > 0]
df_chicago = df_chicago[df_chicago['Trip_Seconds'] >= 60]

# %%
df_chicago.reset_index(drop = True)
# Out:
#                                            Trip_ID  \
# 0         27ad87f629bf14fa3cb894daad514cdad4736f9c
# 1         7a3c9ab6e4da5c35448753e981bb73065a0c0319
# 2         9a9d9902dfa267b88400a22a2c9f0cf74384b372
# 3         235977a4b76994e0506b2c1775ad7b6a616140da
# 4         5e07d8d10a2314fb71214c71ca3f19beab79652d
# ...                                            ...
# 12359780  a155865e7578ddd52ed77443c6fed7f981c694b1
# 12359781  35a5fe3a96ad453a9276112136c934a87379e8a5
# 12359782  f6fa0574a62cab2fec2c9ea2cc075f8ff6ee19e5
# 12359783  de95a68aae83de22d19a7999111f249e90eae812
# 12359784  2520e0373a96d517bfdebf51df22d1cefa0ac2c3
#
#                                                     Taxi_ID  \
# 0         4b38941e0745acdeefe630832a438a59fdaac78640f68a...
# 1         efce437d4bc2a79b12ac131e37789da8fe5e53f37d12c2...
# 2         1a1189d1e9f4f676bbeaf49903912684b94453576a234f...
# 3         99d30118c79bf4b5f037d2d26660bb2dbca0994fc503e2...
# 4         0826a2682f598bf0e39aa460479bc87757bd2fcb72c171...
# ...                                                     ...
# 12359780  cc33cdc1816a9ba9822dd033062f8d414cac183bbfa7fc...
# 12359781  341cead8979074196f3231099ef811c4e905d7031dd6d7...
# 12359782  c01573d08b208b89c0fdf054d7bc2820fe2abb9d326a80...
# 12359783  5866e731fed5c82556c87a73b3ec2e19dd13d4cdc46a34...
# 12359784  c7475fec1fa338d525948b60cc20c8a47905a257c68ef8...
#
#          Trip_Start_Timestamp  Trip_End_Timestamp  Trip_Seconds  Trip_Miles  \
# 0         2013-01-01 00:00:00 2013-01-01 00:15:00         900.0         2.7
# 1         2013-01-01 00:00:00 2013-01-01 00:00:00          60.0         0.3
# 2         2013-01-01 00:00:00 2013-01-01 00:00:00         240.0         0.4
# 3         2013-01-01 00:00:00 2013-01-01 00:30:00        1440.0         1.2
# 4         2013-01-01 00:00:00 2013-01-01 00:30:00        1920.0         0.6
# ...                       ...                 ...           ...         ...
# 12359780  2013-12-31 23:45:00 2013-12-31 23:45:00         536.0         1.6
# 12359781  2013-12-31 23:45:00 2014-01-01 00:15:00        1952.0         8.5
# 12359782  2013-12-31 23:45:00 2013-12-31 23:45:00         262.0         0.9
# 12359783  2013-12-31 23:45:00 2013-12-31 23:45:00         352.0         0.7
# 12359784  2013-12-31 23:45:00 2014-01-01 00:00:00        1141.0         4.4
#
#           Pickup_Census_Tract  Dropoff_Census_Tract  Pickup_Community_Area  \
# 0                         NaN                   NaN                   28.0
# 1                1.703132e+10          1.703132e+10                   32.0
# 2                1.703107e+10          1.703107e+10                    7.0
# 3                1.703198e+10          1.703184e+10                   76.0
# 4                1.703122e+10          1.703104e+10                   22.0
# ...                       ...                   ...                    ...
# 12359780         1.703106e+10          1.703103e+10                    6.0
# 12359781                  NaN                   NaN                   28.0
# 12359782         1.703132e+10          1.703108e+10                   32.0
# 12359783         1.703106e+10          1.703106e+10                    6.0
# 12359784         1.703132e+10          1.703124e+10                   32.0
#
#           Dropoff_Community_Area  ...  Extras  Trip_Total  Payment_Type  \
# 0                            8.0  ...     1.0       11.45          Cash
# 1                           32.0  ...     0.0        3.85          Cash
# 2                            7.0  ...     0.0        4.84          Cash
# 3                           34.0  ...     3.0       42.05          Cash
# 4                            4.0  ...     1.0       25.05          Cash
# ...                          ...  ...     ...         ...           ...
# 12359780                     3.0  ...     0.0        9.85   Credit Card
# 12359781                     6.0  ...     2.0       23.45          Cash
# 12359782                     8.0  ...     2.0        7.25          Cash
# 12359783                     6.0  ...     0.0        7.05   Credit Card
# 12359784                    24.0  ...     1.5       14.55          Cash
#
#           Pickup_Centroid_Latitude  Pickup_Centroid_Longitude  \
# 0                        41.874005                 -87.663518
# 1                        41.870607                 -87.622173
# 2                        41.928967                 -87.656157
# 3                        41.979071                 -87.903040
# 4                        41.921126                 -87.699754
# ...                            ...                        ...
# 12359780                 41.941556                 -87.666289
# 12359781                 41.874005                 -87.663518
# 12359782                 41.884987                 -87.620993
# 12359783                 41.942577                 -87.647079
# 12359784                 41.884987                 -87.620993
#
#                       Pickup_Centroid_Location  Dropoff_Centroid_Latitude  \
# 0          POINT (-87.6635175498 41.874005383)                  41.899602
# 1         POINT (-87.6221729369 41.8706073724)                  41.870607
# 2         POINT (-87.6561568309 41.9289672664)                  41.929047
# 3         POINT (-87.9030396611 41.9790708201)                  41.851018
# 4         POINT (-87.6997544065 41.9211259143)                  41.966834
# ...                                        ...                        ...
# 12359780   POINT (-87.6662888874 41.941555829)                  41.965446
# 12359781   POINT (-87.6635175498 41.874005383)                  41.944227
# 12359782  POINT (-87.6209929134 41.8849871918)                  41.898332
# 12359783   POINT (-87.6470785093 41.942577185)                  41.934540
# 12359784  POINT (-87.6209929134 41.8849871918)                  41.912364
#
#           Dropoff_Centroid_Longitude  \
# 0                         -87.633308
# 1                         -87.622173
# 2                         -87.651311
# 3                         -87.635092
# 4                         -87.684018
# ...                              ...
# 12359780                  -87.663196
# 12359781                  -87.655998
# 12359782                  -87.620763
# 12359783                  -87.643023
# 12359784                  -87.675063
#
#                         Dropoff_Centroid__Location  Community_Areas
# 0              POINT (-87.6333080367 41.899602111)             29.0
# 1             POINT (-87.6221729369 41.8706073724)             38.0
# 2             POINT (-87.6513108767 41.9290469366)             68.0
# 3             POINT (-87.6350918563 41.8510178239)             75.0
# 4             POINT (-87.6840183712 41.9668340674)             23.0
# ...                                            ...              ...
# 12359780      POINT (-87.6631958495 41.9654457842)             57.0
# 12359781      POINT (-87.6559981815 41.9442266014)             29.0
# 12359782      POINT (-87.6207628651 41.8983317935)             38.0
# 12359783  POINT (-87.6430228044 41.93453971580001)             57.0
# 12359784      POINT (-87.6750627566 41.9123643542)             38.0
#
# [12359785 rows x 23 columns]

# %% [markdown]
# ### `Taxi_ID` and driving time:

# %% [markdown]
# We drop the rows where there are null values (NaN) in the column `Taxi_ID`, because otherwise these rows aren't considered in the following duplicate check:

# %%
df_chicago.dropna(subset=['Taxi_ID'],inplace=True)

# %% [markdown]
# Check for rows where there are duplicates in the columns of Taxi ID and the Trip_Start_Timestamp, because the same taxi can't start two trips at the same time. After checking for them, we drop them out of the dataframe:

# %%
df_chicago.duplicated(subset=['Taxi_ID','Trip_Start_Timestamp']).sum()
# Out:
# 1170487

# %%
df_chicago.drop_duplicates(subset=['Taxi_ID','Trip_Start_Timestamp'], inplace = True)

# %% [markdown]
# Now we check if there are rows, where the same Taxi ID has overlapping time ranges. So where the same taxi drives different trips in same time interval. If there are such trips, we drop them such that there remains only one trip with the taxi in the considered time range:

# %%
# checking for Taxi ID with overlapping time ranges

overlap = df_chicago.groupby('Taxi_ID').apply(
    lambda group: group[
        (group['Trip_Start_Timestamp'].lt(group['Trip_End_Timestamp'].shift(-1))) &
        (group['Trip_End_Timestamp'].gt(group['Trip_Start_Timestamp'].shift(-1)))
    ]
)
overlap
# Out:
#                                                                                               Trip_ID  \
# Taxi_ID
# 0044e6c0d091476299b99345501f756b23632a96cbaf40e... 19025754  7f21d680ed72a1d91fe751b41eb0d61e5ec242f9
# 008ca9f6e7dff925f1a18284fb269fc3c781977db68d158... 20741466  47d15cc99cfcdcebba40aa04a06cd52d300e6b19
# 008e4411af8ea511e3990a1d25eb3bd4ef68314d8c2f8f2... 3473615   6044b9ebc729b1843b17cb25f5af4359ae34c8c3
#                                                    19996528  49cd55d18b00ace697ab39b9018b99bc7208ee15
#                                                    20001592  168e51984adb8c60181e83d4589fb431742fda68
# ...                                                                                               ...
# ffb8cefb331d92d05289bb6d84fba73aac7ed8252c6f4b6... 18216275  9ab6011dbfc968741a31b7d268ed78c12ef0423a
# ffc2a618ad19a63fa5e9ce8b1bd68656172b2eac505f0a2... 19690004  4898de351822515f6f557ef0e2923d5612992827
#                                                    20219307  1aa13e5bc1b1f929d7d33efd468d6386c60dd457
#                                                    20247179  fd844638b147cdcd8d3136bc1fad5b93e3cdce66
#                                                    21028219  755d9a49965f24e2e0925f9174dfd058dae3cd74
#
#                                                                                                        Taxi_ID  \
# Taxi_ID
# 0044e6c0d091476299b99345501f756b23632a96cbaf40e... 19025754  0044e6c0d091476299b99345501f756b23632a96cbaf40...
# 008ca9f6e7dff925f1a18284fb269fc3c781977db68d158... 20741466  008ca9f6e7dff925f1a18284fb269fc3c781977db68d15...
# 008e4411af8ea511e3990a1d25eb3bd4ef68314d8c2f8f2... 3473615   008e4411af8ea511e3990a1d25eb3bd4ef68314d8c2f8f...
#                                                    19996528  008e4411af8ea511e3990a1d25eb3bd4ef68314d8c2f8f...
#                                                    20001592  008e4411af8ea511e3990a1d25eb3bd4ef68314d8c2f8f...
# ...                                                                                                        ...
# ffb8cefb331d92d05289bb6d84fba73aac7ed8252c6f4b6... 18216275  ffb8cefb331d92d05289bb6d84fba73aac7ed8252c6f4b...
# ffc2a618ad19a63fa5e9ce8b1bd68656172b2eac505f0a2... 19690004  ffc2a618ad19a63fa5e9ce8b1bd68656172b2eac505f0a...
#                                                    20219307  ffc2a618ad19a63fa5e9ce8b1bd68656172b2eac505f0a...
#                                                    20247179  ffc2a618ad19a63fa5e9ce8b1bd68656172b2eac505f0a...
#                                                    21028219  ffc2a618ad19a63fa5e9ce8b1bd68656172b2eac505f0a...
#
#                                                             Trip_Start_Timestamp  \
# Taxi_ID
# 0044e6c0d091476299b99345501f756b23632a96cbaf40e... 19025754  2013-11-24 00:30:00
# 008ca9f6e7dff925f1a18284fb269fc3c781977db68d158... 20741466  2013-12-17 20:00:00
# 008e4411af8ea511e3990a1d25eb3bd4ef68314d8c2f8f2... 3473615   2013-03-16 13:45:00
#                                                    19996528  2013-12-08 04:30:00
#                                                    20001592  2013-12-08 09:00:00
# ...                                                                          ...
# ffb8cefb331d92d05289bb6d84fba73aac7ed8252c6f4b6... 18216275  2013-11-13 14:30:00
# ffc2a618ad19a63fa5e9ce8b1bd68656172b2eac505f0a2... 19690004  2013-12-05 06:00:00
#                                                    20219307  2013-12-11 14:45:00
#                                                    20247179  2013-12-11 20:30:00
#                                                    21028219  2013-12-21 06:30:00
#
#                                                              Trip_End_Timestamp  \
# Taxi_ID
# 0044e6c0d091476299b99345501f756b23632a96cbaf40e... 19025754 2013-11-24 01:00:00
# 008ca9f6e7dff925f1a18284fb269fc3c781977db68d158... 20741466 2013-12-17 20:30:00
# 008e4411af8ea511e3990a1d25eb3bd4ef68314d8c2f8f2... 3473615  2013-03-17 00:00:00
#                                                    19996528 2013-12-08 05:45:00
#                                                    20001592 2013-12-08 09:30:00
# ...                                                                         ...
# ffb8cefb331d92d05289bb6d84fba73aac7ed8252c6f4b6... 18216275 2013-11-14 00:00:00
# ffc2a618ad19a63fa5e9ce8b1bd68656172b2eac505f0a2... 19690004 2013-12-05 06:45:00
#                                                    20219307 2013-12-11 15:15:00
#                                                    20247179 2013-12-11 21:00:00
#                                                    21028219 2013-12-21 07:00:00
#
#                                                              Trip_Seconds  \
# Taxi_ID
# 0044e6c0d091476299b99345501f756b23632a96cbaf40e... 19025754        1200.0
# 008ca9f6e7dff925f1a18284fb269fc3c781977db68d158... 20741466        1620.0
# 008e4411af8ea511e3990a1d25eb3bd4ef68314d8c2f8f2... 3473615        36720.0
#                                                    19996528        4320.0
#                                                    20001592        1260.0
# ...                                                                   ...
# ffb8cefb331d92d05289bb6d84fba73aac7ed8252c6f4b6... 18216275       33960.0
# ffc2a618ad19a63fa5e9ce8b1bd68656172b2eac505f0a2... 19690004        2040.0
#                                                    20219307        1560.0
#                                                    20247179        1380.0
#                                                    21028219        1200.0
#
#                                                              Trip_Miles  \
# Taxi_ID
# 0044e6c0d091476299b99345501f756b23632a96cbaf40e... 19025754         6.8
# 008ca9f6e7dff925f1a18284fb269fc3c781977db68d158... 20741466         9.6
# 008e4411af8ea511e3990a1d25eb3bd4ef68314d8c2f8f2... 3473615          0.8
#                                                    19996528         9.3
#                                                    20001592        17.8
# ...                                                                 ...
# ffb8cefb331d92d05289bb6d84fba73aac7ed8252c6f4b6... 18216275         0.6
# ffc2a618ad19a63fa5e9ce8b1bd68656172b2eac505f0a2... 19690004        19.6
#                                                    20219307        33.4
#                                                    20247179        13.8
#                                                    21028219         6.9
#
#                                                              Pickup_Census_Tract  \
# Taxi_ID
# 0044e6c0d091476299b99345501f756b23632a96cbaf40e... 19025754                  NaN
# 008ca9f6e7dff925f1a18284fb269fc3c781977db68d158... 20741466                  NaN
# 008e4411af8ea511e3990a1d25eb3bd4ef68314d8c2f8f2... 3473615          1.703108e+10
#                                                    19996528                  NaN
#                                                    20001592         1.703108e+10
# ...                                                                          ...
# ffb8cefb331d92d05289bb6d84fba73aac7ed8252c6f4b6... 18216275         1.703184e+10
# ffc2a618ad19a63fa5e9ce8b1bd68656172b2eac505f0a2... 19690004         1.703128e+10
#                                                    20219307         1.703183e+10
#                                                    20247179                  NaN
#                                                    21028219                  NaN
#
#                                                              Dropoff_Census_Tract  \
# Taxi_ID
# 0044e6c0d091476299b99345501f756b23632a96cbaf40e... 19025754                   NaN
# 008ca9f6e7dff925f1a18284fb269fc3c781977db68d158... 20741466                   NaN
# 008e4411af8ea511e3990a1d25eb3bd4ef68314d8c2f8f2... 3473615           1.703108e+10
#                                                    19996528                   NaN
#                                                    20001592          1.703198e+10
# ...                                                                           ...
# ffb8cefb331d92d05289bb6d84fba73aac7ed8252c6f4b6... 18216275          1.703128e+10
# ffc2a618ad19a63fa5e9ce8b1bd68656172b2eac505f0a2... 19690004          1.703133e+10
#                                                    20219307          1.703198e+10
#                                                    20247179                   NaN
#                                                    21028219                   NaN
#
#                                                              Pickup_Community_Area  \
# Taxi_ID
# 0044e6c0d091476299b99345501f756b23632a96cbaf40e... 19025754                   22.0
# 008ca9f6e7dff925f1a18284fb269fc3c781977db68d158... 20741466                   76.0
# 008e4411af8ea511e3990a1d25eb3bd4ef68314d8c2f8f2... 3473615                     8.0
#                                                    19996528                    6.0
#                                                    20001592                    8.0
# ...                                                                            ...
# ffb8cefb331d92d05289bb6d84fba73aac7ed8252c6f4b6... 18216275                   32.0
# ffc2a618ad19a63fa5e9ce8b1bd68656172b2eac505f0a2... 19690004                   28.0
#                                                    20219307                   28.0
#                                                    20247179                   56.0
#                                                    21028219                    3.0
#
#                                                              Dropoff_Community_Area  \
# Taxi_ID
# 0044e6c0d091476299b99345501f756b23632a96cbaf40e... 19025754                     2.0
# 008ca9f6e7dff925f1a18284fb269fc3c781977db68d158... 20741466                    12.0
# 008e4411af8ea511e3990a1d25eb3bd4ef68314d8c2f8f2... 3473615                      8.0
#                                                    19996528                     8.0
#                                                    20001592                    76.0
# ...                                                                             ...
# ffb8cefb331d92d05289bb6d84fba73aac7ed8252c6f4b6... 18216275                    28.0
# ffc2a618ad19a63fa5e9ce8b1bd68656172b2eac505f0a2... 19690004                    33.0
#                                                    20219307                    76.0
#                                                    20247179                    41.0
#                                                    21028219                    15.0
#
#                                                              ...  Extras  \
# Taxi_ID                                                      ...
# 0044e6c0d091476299b99345501f756b23632a96cbaf40e... 19025754  ...     1.5
# 008ca9f6e7dff925f1a18284fb269fc3c781977db68d158... 20741466  ...     2.0
# 008e4411af8ea511e3990a1d25eb3bd4ef68314d8c2f8f2... 3473615   ...     1.0
#                                                    19996528  ...     0.0
#                                                    20001592  ...     1.0
# ...                                                          ...     ...
# ffb8cefb331d92d05289bb6d84fba73aac7ed8252c6f4b6... 18216275  ...     0.0
# ffc2a618ad19a63fa5e9ce8b1bd68656172b2eac505f0a2... 19690004  ...     2.0
#                                                    20219307  ...     2.0
#                                                    20247179  ...     2.0
#                                                    21028219  ...     0.0
#
#                                                              Trip_Total  \
# Taxi_ID
# 0044e6c0d091476299b99345501f756b23632a96cbaf40e... 19025754       18.75
# 008ca9f6e7dff925f1a18284fb269fc3c781977db68d158... 20741466       29.85
# 008e4411af8ea511e3990a1d25eb3bd4ef68314d8c2f8f2... 3473615         6.25
#                                                    19996528       36.65
#                                                    20001592       43.98
# ...                                                                 ...
# ffb8cefb331d92d05289bb6d84fba73aac7ed8252c6f4b6... 18216275        4.84
# ffc2a618ad19a63fa5e9ce8b1bd68656172b2eac505f0a2... 19690004       42.45
#                                                    20219307       66.45
#                                                    20247179       31.25
#                                                    21028219       17.05
#
#                                                              Payment_Type  \
# Taxi_ID
# 0044e6c0d091476299b99345501f756b23632a96cbaf40e... 19025754          Cash
# 008ca9f6e7dff925f1a18284fb269fc3c781977db68d158... 20741466   Credit Card
# 008e4411af8ea511e3990a1d25eb3bd4ef68314d8c2f8f2... 3473615           Cash
#                                                    19996528          Cash
#                                                    20001592   Credit Card
# ...                                                                   ...
# ffb8cefb331d92d05289bb6d84fba73aac7ed8252c6f4b6... 18216275          Cash
# ffc2a618ad19a63fa5e9ce8b1bd68656172b2eac505f0a2... 19690004          Cash
#                                                    20219307          Cash
#                                                    20247179          Cash
#                                                    21028219          Cash
#
#                                                              Pickup_Centroid_Latitude  \
# Taxi_ID
# 0044e6c0d091476299b99345501f756b23632a96cbaf40e... 19025754                 41.922761
# 008ca9f6e7dff925f1a18284fb269fc3c781977db68d158... 20741466                 41.980264
# 008e4411af8ea511e3990a1d25eb3bd4ef68314d8c2f8f2... 3473615                  41.893216
#                                                    19996528                 41.944227
#                                                    20001592                 41.895033
# ...                                                                               ...
# ffb8cefb331d92d05289bb6d84fba73aac7ed8252c6f4b6... 18216275                 41.880994
# ffc2a618ad19a63fa5e9ce8b1bd68656172b2eac505f0a2... 19690004                 41.879255
#                                                    20219307                 41.885281
#                                                    20247179                 41.792592
#                                                    21028219                 41.965812
#
#                                                              Pickup_Centroid_Longitude  \
# Taxi_ID
# 0044e6c0d091476299b99345501f756b23632a96cbaf40e... 19025754                 -87.699155
# 008ca9f6e7dff925f1a18284fb269fc3c781977db68d158... 20741466                 -87.913625
# 008e4411af8ea511e3990a1d25eb3bd4ef68314d8c2f8f2... 3473615                  -87.637844
#                                                    19996528                 -87.655998
#                                                    20001592                 -87.619711
# ...                                                                                ...
# ffb8cefb331d92d05289bb6d84fba73aac7ed8252c6f4b6... 18216275                 -87.632746
# ffc2a618ad19a63fa5e9ce8b1bd68656172b2eac505f0a2... 19690004                 -87.642649
#                                                    20219307                 -87.657233
#                                                    20247179                 -87.769615
#                                                    21028219                 -87.655879
#
#                                                                              Pickup_Centroid_Location  \
# Taxi_ID
# 0044e6c0d091476299b99345501f756b23632a96cbaf40e... 19025754  POINT (-87.69915534320002 41.9227606205)
# 008ca9f6e7dff925f1a18284fb269fc3c781977db68d158... 20741466       POINT (-87.913624596 41.9802643146)
# 008e4411af8ea511e3990a1d25eb3bd4ef68314d8c2f8f2... 3473615       POINT (-87.6378442095 41.8932163595)
#                                                    19996528      POINT (-87.6559981815 41.9442266014)
#                                                    20001592      POINT (-87.6197106717 41.8950334495)
# ...                                                                                               ...
# ffb8cefb331d92d05289bb6d84fba73aac7ed8252c6f4b6... 18216275      POINT (-87.6327464887 41.8809944707)
# ffc2a618ad19a63fa5e9ce8b1bd68656172b2eac505f0a2... 19690004       POINT (-87.642648998 41.8792550844)
#                                                    20219307      POINT (-87.6572331997 41.8852813201)
#                                                    20247179      POINT (-87.7696154528 41.7925923603)
#                                                    21028219        POINT (-87.6558787862 41.96581197)
#
#                                                              Dropoff_Centroid_Latitude  \
# Taxi_ID
# 0044e6c0d091476299b99345501f756b23632a96cbaf40e... 19025754                  42.001571
# 008ca9f6e7dff925f1a18284fb269fc3c781977db68d158... 20741466                  41.993930
# 008e4411af8ea511e3990a1d25eb3bd4ef68314d8c2f8f2... 3473615                   41.890922
#                                                    19996528                  41.899602
#                                                    20001592                  41.979071
# ...                                                                                ...
# ffb8cefb331d92d05289bb6d84fba73aac7ed8252c6f4b6... 18216275                  41.879255
# ffc2a618ad19a63fa5e9ce8b1bd68656172b2eac505f0a2... 19690004                  41.859350
#                                                    20219307                  41.979071
#                                                    20247179                  41.794090
#                                                    21028219                  41.954028
#
#                                                              Dropoff_Centroid_Longitude  \
# Taxi_ID
# 0044e6c0d091476299b99345501f756b23632a96cbaf40e... 19025754                  -87.695013
# 008ca9f6e7dff925f1a18284fb269fc3c781977db68d158... 20741466                  -87.758354
# 008e4411af8ea511e3990a1d25eb3bd4ef68314d8c2f8f2... 3473615                   -87.618868
#                                                    19996528                  -87.633308
#                                                    20001592                  -87.903040
# ...                                                                                 ...
# ffb8cefb331d92d05289bb6d84fba73aac7ed8252c6f4b6... 18216275                  -87.642649
# ffc2a618ad19a63fa5e9ce8b1bd68656172b2eac505f0a2... 19690004                  -87.617358
#                                                    20219307                  -87.903040
#                                                    20247179                  -87.592311
#                                                    21028219                  -87.763399
#
#                                                                        Dropoff_Centroid__Location  \
# Taxi_ID
# 0044e6c0d091476299b99345501f756b23632a96cbaf40e... 19025754   POINT (-87.6950125892 42.001571027)
# 008ca9f6e7dff925f1a18284fb269fc3c781977db68d158... 20741466  POINT (-87.7583535876 41.9939301285)
# 008e4411af8ea511e3990a1d25eb3bd4ef68314d8c2f8f2... 3473615   POINT (-87.6188683546 41.8909220259)
#                                                    19996528   POINT (-87.6333080367 41.899602111)
#                                                    20001592  POINT (-87.9030396611 41.9790708201)
# ...                                                                                           ...
# ffb8cefb331d92d05289bb6d84fba73aac7ed8252c6f4b6... 18216275   POINT (-87.642648998 41.8792550844)
# ffc2a618ad19a63fa5e9ce8b1bd68656172b2eac505f0a2... 19690004   POINT (-87.6173580061 41.859349715)
#                                                    20219307  POINT (-87.9030396611 41.9790708201)
#                                                    20247179    POINT (-87.592310855 41.794090253)
#                                                    21028219  POINT (-87.7633990316 41.9540276487)
#
#                                                              Community_Areas
# Taxi_ID
# 0044e6c0d091476299b99345501f756b23632a96cbaf40e... 19025754             23.0
# 008ca9f6e7dff925f1a18284fb269fc3c781977db68d158... 20741466             75.0
# 008e4411af8ea511e3990a1d25eb3bd4ef68314d8c2f8f2... 3473615              37.0
#                                                    19996528             57.0
#                                                    20001592             37.0
# ...                                                                      ...
# ffb8cefb331d92d05289bb6d84fba73aac7ed8252c6f4b6... 18216275             38.0
# ffc2a618ad19a63fa5e9ce8b1bd68656172b2eac505f0a2... 19690004             29.0
#                                                    20219307             29.0
#                                                    20247179             53.0
#                                                    21028219             31.0
#
# [7975 rows x 23 columns]

# %%
# taking the indices of the rows with overlapping time ranges

overlap_indices = overlap.index.get_level_values(1)
overlap_indices
# Out:
# Int64Index([19025754, 20741466,  3473615, 19996528, 20001592, 20006903,
#             20007649, 20008377, 20013170, 20761590,
#             ...
#              7868905,  9335889, 10002471, 14308992, 16223479, 18216275,
#             19690004, 20219307, 20247179, 21028219],
#            dtype='int64', length=7975)

# %%
# drop these rows (trips)

df_chicago = df_chicago.drop(overlap_indices, axis= 0)
df_chicago.reset_index(drop = True)
# Out:
#                                            Trip_ID  \
# 0         27ad87f629bf14fa3cb894daad514cdad4736f9c
# 1         7a3c9ab6e4da5c35448753e981bb73065a0c0319
# 2         9a9d9902dfa267b88400a22a2c9f0cf74384b372
# 3         235977a4b76994e0506b2c1775ad7b6a616140da
# 4         5e07d8d10a2314fb71214c71ca3f19beab79652d
# ...                                            ...
# 11181029  a155865e7578ddd52ed77443c6fed7f981c694b1
# 11181030  35a5fe3a96ad453a9276112136c934a87379e8a5
# 11181031  f6fa0574a62cab2fec2c9ea2cc075f8ff6ee19e5
# 11181032  de95a68aae83de22d19a7999111f249e90eae812
# 11181033  2520e0373a96d517bfdebf51df22d1cefa0ac2c3
#
#                                                     Taxi_ID  \
# 0         4b38941e0745acdeefe630832a438a59fdaac78640f68a...
# 1         efce437d4bc2a79b12ac131e37789da8fe5e53f37d12c2...
# 2         1a1189d1e9f4f676bbeaf49903912684b94453576a234f...
# 3         99d30118c79bf4b5f037d2d26660bb2dbca0994fc503e2...
# 4         0826a2682f598bf0e39aa460479bc87757bd2fcb72c171...
# ...                                                     ...
# 11181029  cc33cdc1816a9ba9822dd033062f8d414cac183bbfa7fc...
# 11181030  341cead8979074196f3231099ef811c4e905d7031dd6d7...
# 11181031  c01573d08b208b89c0fdf054d7bc2820fe2abb9d326a80...
# 11181032  5866e731fed5c82556c87a73b3ec2e19dd13d4cdc46a34...
# 11181033  c7475fec1fa338d525948b60cc20c8a47905a257c68ef8...
#
#          Trip_Start_Timestamp  Trip_End_Timestamp  Trip_Seconds  Trip_Miles  \
# 0         2013-01-01 00:00:00 2013-01-01 00:15:00         900.0         2.7
# 1         2013-01-01 00:00:00 2013-01-01 00:00:00          60.0         0.3
# 2         2013-01-01 00:00:00 2013-01-01 00:00:00         240.0         0.4
# 3         2013-01-01 00:00:00 2013-01-01 00:30:00        1440.0         1.2
# 4         2013-01-01 00:00:00 2013-01-01 00:30:00        1920.0         0.6
# ...                       ...                 ...           ...         ...
# 11181029  2013-12-31 23:45:00 2013-12-31 23:45:00         536.0         1.6
# 11181030  2013-12-31 23:45:00 2014-01-01 00:15:00        1952.0         8.5
# 11181031  2013-12-31 23:45:00 2013-12-31 23:45:00         262.0         0.9
# 11181032  2013-12-31 23:45:00 2013-12-31 23:45:00         352.0         0.7
# 11181033  2013-12-31 23:45:00 2014-01-01 00:00:00        1141.0         4.4
#
#           Pickup_Census_Tract  Dropoff_Census_Tract  Pickup_Community_Area  \
# 0                         NaN                   NaN                   28.0
# 1                1.703132e+10          1.703132e+10                   32.0
# 2                1.703107e+10          1.703107e+10                    7.0
# 3                1.703198e+10          1.703184e+10                   76.0
# 4                1.703122e+10          1.703104e+10                   22.0
# ...                       ...                   ...                    ...
# 11181029         1.703106e+10          1.703103e+10                    6.0
# 11181030                  NaN                   NaN                   28.0
# 11181031         1.703132e+10          1.703108e+10                   32.0
# 11181032         1.703106e+10          1.703106e+10                    6.0
# 11181033         1.703132e+10          1.703124e+10                   32.0
#
#           Dropoff_Community_Area  ...  Extras  Trip_Total  Payment_Type  \
# 0                            8.0  ...     1.0       11.45          Cash
# 1                           32.0  ...     0.0        3.85          Cash
# 2                            7.0  ...     0.0        4.84          Cash
# 3                           34.0  ...     3.0       42.05          Cash
# 4                            4.0  ...     1.0       25.05          Cash
# ...                          ...  ...     ...         ...           ...
# 11181029                     3.0  ...     0.0        9.85   Credit Card
# 11181030                     6.0  ...     2.0       23.45          Cash
# 11181031                     8.0  ...     2.0        7.25          Cash
# 11181032                     6.0  ...     0.0        7.05   Credit Card
# 11181033                    24.0  ...     1.5       14.55          Cash
#
#           Pickup_Centroid_Latitude  Pickup_Centroid_Longitude  \
# 0                        41.874005                 -87.663518
# 1                        41.870607                 -87.622173
# 2                        41.928967                 -87.656157
# 3                        41.979071                 -87.903040
# 4                        41.921126                 -87.699754
# ...                            ...                        ...
# 11181029                 41.941556                 -87.666289
# 11181030                 41.874005                 -87.663518
# 11181031                 41.884987                 -87.620993
# 11181032                 41.942577                 -87.647079
# 11181033                 41.884987                 -87.620993
#
#                       Pickup_Centroid_Location  Dropoff_Centroid_Latitude  \
# 0          POINT (-87.6635175498 41.874005383)                  41.899602
# 1         POINT (-87.6221729369 41.8706073724)                  41.870607
# 2         POINT (-87.6561568309 41.9289672664)                  41.929047
# 3         POINT (-87.9030396611 41.9790708201)                  41.851018
# 4         POINT (-87.6997544065 41.9211259143)                  41.966834
# ...                                        ...                        ...
# 11181029   POINT (-87.6662888874 41.941555829)                  41.965446
# 11181030   POINT (-87.6635175498 41.874005383)                  41.944227
# 11181031  POINT (-87.6209929134 41.8849871918)                  41.898332
# 11181032   POINT (-87.6470785093 41.942577185)                  41.934540
# 11181033  POINT (-87.6209929134 41.8849871918)                  41.912364
#
#           Dropoff_Centroid_Longitude  \
# 0                         -87.633308
# 1                         -87.622173
# 2                         -87.651311
# 3                         -87.635092
# 4                         -87.684018
# ...                              ...
# 11181029                  -87.663196
# 11181030                  -87.655998
# 11181031                  -87.620763
# 11181032                  -87.643023
# 11181033                  -87.675063
#
#                         Dropoff_Centroid__Location  Community_Areas
# 0              POINT (-87.6333080367 41.899602111)             29.0
# 1             POINT (-87.6221729369 41.8706073724)             38.0
# 2             POINT (-87.6513108767 41.9290469366)             68.0
# 3             POINT (-87.6350918563 41.8510178239)             75.0
# 4             POINT (-87.6840183712 41.9668340674)             23.0
# ...                                            ...              ...
# 11181029      POINT (-87.6631958495 41.9654457842)             57.0
# 11181030      POINT (-87.6559981815 41.9442266014)             29.0
# 11181031      POINT (-87.6207628651 41.8983317935)             38.0
# 11181032  POINT (-87.6430228044 41.93453971580001)             57.0
# 11181033      POINT (-87.6750627566 41.9123643542)             38.0
#
# [11181034 rows x 23 columns]

# %% [markdown]
# ### Price related columns:

# %%
# we are dropping the column Trip_Total, because it sums up all the other columns which refer to the prices
# this means the information of this column are redundant

df_chicago.drop(columns=['Trip_Total'],inplace=True)

# %%
print(f"Number of null values (NaN) in column 'Fare': {len(df_chicago['Fare'])-len(df_chicago['Fare'].dropna())}")
print(f"Number of null values (NaN) in column 'Tips': {len(df_chicago['Tips'])-len(df_chicago['Tips'].dropna())}")
print(f"Number of null values (NaN) in column 'Tolls': {len(df_chicago['Tolls'])-len(df_chicago['Tolls'].dropna())}")
print(f"Number of null values (NaN) in column 'Extras': {len(df_chicago['Extras'])-len(df_chicago['Extras'].dropna())}")
# Out:
# Number of null values (NaN) in column 'Fare': 174
# Number of null values (NaN) in column 'Tips': 174
# Number of null values (NaN) in column 'Tolls': 279748
# Number of null values (NaN) in column 'Extras': 174

# %%
df_chicago.dropna(subset=['Fare'], inplace = True)
df_chicago.dropna(subset=['Tips'], inplace = True)
df_chicago.dropna(subset=['Tolls'], inplace = True)
df_chicago.dropna(subset=['Extras'], inplace = True)

# %%
# check for zeros/negative values in columns: Fare (Tarif, Preis), Tips, Tolls (Maut) and Extras

fare_ = (df_chicago['Fare'] <= 0).sum()
tips_ = (df_chicago['Tips'] < 0).sum()
tolls_ = (df_chicago['Tolls'] < 0).sum()
extras_ = (df_chicago['Extras'] < 0).sum()
print(fare_)
print(tips_)
print(tolls_)
print(extras_)
# Out:
# 7130
# 0
# 0
# 0

# %%
df_chicago = df_chicago[df_chicago['Fare'] > 0]
df_chicago.reset_index(drop = True)
# Out:
#                                            Trip_ID  \
# 0         27ad87f629bf14fa3cb894daad514cdad4736f9c
# 1         7a3c9ab6e4da5c35448753e981bb73065a0c0319
# 2         9a9d9902dfa267b88400a22a2c9f0cf74384b372
# 3         235977a4b76994e0506b2c1775ad7b6a616140da
# 4         5e07d8d10a2314fb71214c71ca3f19beab79652d
# ...                                            ...
# 10894151  31c089272f9d89049137048298daf08519919866
# 10894152  48d1a333a1f96e01f26ff91ae523c57cc5b9927e
# 10894153  916e0f71e564bd91fbce7a1a9e2d6b9bd625f999
# 10894154  3dbdf16b89f130d633861e7b18e473e30edbc693
# 10894155  dd6218db5183105f49d9c6d68ca90b4ab16b192c
#
#                                                     Taxi_ID  \
# 0         4b38941e0745acdeefe630832a438a59fdaac78640f68a...
# 1         efce437d4bc2a79b12ac131e37789da8fe5e53f37d12c2...
# 2         1a1189d1e9f4f676bbeaf49903912684b94453576a234f...
# 3         99d30118c79bf4b5f037d2d26660bb2dbca0994fc503e2...
# 4         0826a2682f598bf0e39aa460479bc87757bd2fcb72c171...
# ...                                                     ...
# 10894151  b56d49bc42507f35096478dd9613ed6aa7978739e34a99...
# 10894152  d94ecbd1167693d3854fac6b4d884eae97f0ba5f43e5a6...
# 10894153  fb4631333362d071fed26bfadd6cbb59d2f5d794d1288d...
# 10894154  1d073bc6f4c8562385fc42362405825c44b082b5463d82...
# 10894155  330a881b0f3d1450ebb5825aec2551ee4cd5f7c309312b...
#
#          Trip_Start_Timestamp  Trip_End_Timestamp  Trip_Seconds  Trip_Miles  \
# 0         2013-01-01 00:00:00 2013-01-01 00:15:00         900.0         2.7
# 1         2013-01-01 00:00:00 2013-01-01 00:00:00          60.0         0.3
# 2         2013-01-01 00:00:00 2013-01-01 00:00:00         240.0         0.4
# 3         2013-01-01 00:00:00 2013-01-01 00:30:00        1440.0         1.2
# 4         2013-01-01 00:00:00 2013-01-01 00:30:00        1920.0         0.6
# ...                       ...                 ...           ...         ...
# 10894151  2013-12-31 23:45:00 2014-01-01 00:30:00        2040.0         8.6
# 10894152  2013-12-31 23:45:00 2014-01-01 00:00:00        1020.0         6.5
# 10894153  2013-12-31 23:45:00 2014-01-01 00:00:00         300.0         0.7
# 10894154  2013-12-31 23:45:00 2014-01-01 00:15:00        2520.0        10.9
# 10894155  2013-12-31 23:45:00 2014-01-01 00:00:00         420.0         1.4
#
#           Pickup_Census_Tract  Dropoff_Census_Tract  Pickup_Community_Area  \
# 0                         NaN                   NaN                   28.0
# 1                1.703132e+10          1.703132e+10                   32.0
# 2                1.703107e+10          1.703107e+10                    7.0
# 3                1.703198e+10          1.703184e+10                   76.0
# 4                1.703122e+10          1.703104e+10                   22.0
# ...                       ...                   ...                    ...
# 10894151                  NaN                   NaN                   30.0
# 10894152         1.703103e+10          1.703108e+10                    3.0
# 10894153         1.703133e+10          1.703133e+10                   33.0
# 10894154                  NaN                   NaN                   61.0
# 10894155                  NaN                   NaN                   14.0
#
#           Dropoff_Community_Area  ...  Tolls  Extras  Payment_Type  \
# 0                            8.0  ...    0.0     1.0          Cash
# 1                           32.0  ...    0.0     0.0          Cash
# 2                            7.0  ...    0.0     0.0          Cash
# 3                           34.0  ...    0.0     3.0          Cash
# 4                            4.0  ...    0.0     1.0          Cash
# ...                          ...  ...    ...     ...           ...
# 10894151                    14.0  ...    0.0     1.0          Cash
# 10894152                     8.0  ...    0.0     0.0   Credit Card
# 10894153                    33.0  ...    0.0     1.0          Cash
# 10894154                    22.0  ...    0.0     0.0          Cash
# 10894155                    14.0  ...    0.0     1.0          Cash
#
#           Pickup_Centroid_Latitude Pickup_Centroid_Longitude  \
# 0                        41.874005                -87.663518
# 1                        41.870607                -87.622173
# 2                        41.928967                -87.656157
# 3                        41.979071                -87.903040
# 4                        41.921126                -87.699754
# ...                            ...                       ...
# 10894151                 41.839087                -87.714004
# 10894152                 41.972668                -87.663865
# 10894153                 41.859350                -87.617358
# 10894154                 41.809018                -87.659167
# 10894155                 41.968069                -87.721559
#
#                       Pickup_Centroid_Location  Dropoff_Centroid_Latitude  \
# 0          POINT (-87.6635175498 41.874005383)                  41.899602
# 1         POINT (-87.6221729369 41.8706073724)                  41.870607
# 2         POINT (-87.6561568309 41.9289672664)                  41.929047
# 3         POINT (-87.9030396611 41.9790708201)                  41.851018
# 4         POINT (-87.6997544065 41.9211259143)                  41.966834
# ...                                        ...                        ...
# 10894151   POINT (-87.714003807 41.8390869059)                  41.968069
# 10894152  POINT (-87.6638654956 41.9726679555)                  41.892508
# 10894153   POINT (-87.6173580061 41.859349715)                  41.859350
# 10894154  POINT (-87.6591665992 41.8090182499)                  41.922761
# 10894155      POINT (-87.7215590627 41.968069)                  41.968069
#
#          Dropoff_Centroid_Longitude                Dropoff_Centroid__Location  \
# 0                        -87.633308       POINT (-87.6333080367 41.899602111)
# 1                        -87.622173      POINT (-87.6221729369 41.8706073724)
# 2                        -87.651311      POINT (-87.6513108767 41.9290469366)
# 3                        -87.635092      POINT (-87.6350918563 41.8510178239)
# 4                        -87.684018      POINT (-87.6840183712 41.9668340674)
# ...                             ...                                       ...
# 10894151                 -87.721559          POINT (-87.7215590627 41.968069)
# 10894152                 -87.626215      POINT (-87.6262149064 41.8925077809)
# 10894153                 -87.617358       POINT (-87.6173580061 41.859349715)
# 10894154                 -87.699155  POINT (-87.69915534320002 41.9227606205)
# 10894155                 -87.721559          POINT (-87.7215590627 41.968069)
#
#           Community_Areas
# 0                    29.0
# 1                    38.0
# 2                    68.0
# 3                    75.0
# 4                    23.0
# ...                   ...
# 10894151             32.0
# 10894152             31.0
# 10894153             34.0
# 10894154             59.0
# 10894155             14.0
#
# [10894156 rows x 22 columns]

# %%
df_chicago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10894156 entries, 0 to 21638577
# Data columns (total 22 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   Trip_ID                     object
#  1   Taxi_ID                     object
#  2   Trip_Start_Timestamp        datetime64[ns]
#  3   Trip_End_Timestamp          datetime64[ns]
#  4   Trip_Seconds                float64
#  5   Trip_Miles                  float64
#  6   Pickup_Census_Tract         float64
#  7   Dropoff_Census_Tract        float64
#  8   Pickup_Community_Area       float64
#  9   Dropoff_Community_Area      float64
#  10  Fare                        float64
#  11  Tips                        float64
#  12  Tolls                       float64
#  13  Extras                      float64
#  14  Payment_Type                object
#  15  Pickup_Centroid_Latitude    float64
#  16  Pickup_Centroid_Longitude   float64
#  17  Pickup_Centroid_Location    object
#  18  Dropoff_Centroid_Latitude   float64
#  19  Dropoff_Centroid_Longitude  float64
#  20  Dropoff_Centroid__Location  object
#  21  Community_Areas             float64
# dtypes: datetime64[ns](2), float64(15), object(5)
# memory usage: 1.9+ GB

# %% [markdown]
# ## Edit features:

# %% [markdown]
# **Rounding `Trip_Start_Timestamp` and `Trip_End_Timestamp` to hour**

# %%
# Preserving the original timestamps
df_chicago['Original_Trip_Start_Timestamp'] = df_chicago['Trip_Start_Timestamp']
df_chicago['Original_Trip_End_Timestamp'] = df_chicago['Trip_End_Timestamp']

# Rounding time of df_chicago to hour

# rounding hour down in first step and store it in 'Trip_Start_Timestamp_2'
# than if 0-30 leave it like that, for 31-59 add one hour: 'Trip_Start_Timestamp_2'
# store the rounded values in 'Trip_Start_Timestamp' and drop the other column
df_chicago['Trip_Start_Timestamp_2'] = df_chicago['Trip_Start_Timestamp'].dt.floor('H')
df_chicago.loc[df_chicago['Trip_Start_Timestamp'].dt.minute > 30, 'Trip_Start_Timestamp_2'] += pd.Timedelta(hours=1)
df_chicago['Trip_Start_Timestamp'] = df_chicago['Trip_Start_Timestamp_2']
df_chicago.drop(columns = ['Trip_Start_Timestamp_2'], inplace= True)

df_chicago['Trip_End_Timestamp_2'] = df_chicago['Trip_End_Timestamp'].dt.floor('H')
df_chicago.loc[df_chicago['Trip_End_Timestamp'].dt.minute > 30, 'Trip_End_Timestamp_2'] += pd.Timedelta(hours=1)
df_chicago['Trip_End_Timestamp'] = df_chicago['Trip_End_Timestamp_2']
df_chicago.drop(columns = ['Trip_End_Timestamp_2'], inplace= True)

df_chicago
# Out:
#                                            Trip_ID  \
# 0         27ad87f629bf14fa3cb894daad514cdad4736f9c
# 1         7a3c9ab6e4da5c35448753e981bb73065a0c0319
# 2         9a9d9902dfa267b88400a22a2c9f0cf74384b372
# 8         235977a4b76994e0506b2c1775ad7b6a616140da
# 15        5e07d8d10a2314fb71214c71ca3f19beab79652d
# ...                                            ...
# 21638573  31c089272f9d89049137048298daf08519919866
# 21638574  48d1a333a1f96e01f26ff91ae523c57cc5b9927e
# 21638575  916e0f71e564bd91fbce7a1a9e2d6b9bd625f999
# 21638576  3dbdf16b89f130d633861e7b18e473e30edbc693
# 21638577  dd6218db5183105f49d9c6d68ca90b4ab16b192c
#
#                                                     Taxi_ID  \
# 0         4b38941e0745acdeefe630832a438a59fdaac78640f68a...
# 1         efce437d4bc2a79b12ac131e37789da8fe5e53f37d12c2...
# 2         1a1189d1e9f4f676bbeaf49903912684b94453576a234f...
# 8         99d30118c79bf4b5f037d2d26660bb2dbca0994fc503e2...
# 15        0826a2682f598bf0e39aa460479bc87757bd2fcb72c171...
# ...                                                     ...
# 21638573  b56d49bc42507f35096478dd9613ed6aa7978739e34a99...
# 21638574  d94ecbd1167693d3854fac6b4d884eae97f0ba5f43e5a6...
# 21638575  fb4631333362d071fed26bfadd6cbb59d2f5d794d1288d...
# 21638576  1d073bc6f4c8562385fc42362405825c44b082b5463d82...
# 21638577  330a881b0f3d1450ebb5825aec2551ee4cd5f7c309312b...
#
#          Trip_Start_Timestamp Trip_End_Timestamp  Trip_Seconds  Trip_Miles  \
# 0                  2013-01-01         2013-01-01         900.0         2.7
# 1                  2013-01-01         2013-01-01          60.0         0.3
# 2                  2013-01-01         2013-01-01         240.0         0.4
# 8                  2013-01-01         2013-01-01        1440.0         1.2
# 15                 2013-01-01         2013-01-01        1920.0         0.6
# ...                       ...                ...           ...         ...
# 21638573           2014-01-01         2014-01-01        2040.0         8.6
# 21638574           2014-01-01         2014-01-01        1020.0         6.5
# 21638575           2014-01-01         2014-01-01         300.0         0.7
# 21638576           2014-01-01         2014-01-01        2520.0        10.9
# 21638577           2014-01-01         2014-01-01         420.0         1.4
#
#           Pickup_Census_Tract  Dropoff_Census_Tract  Pickup_Community_Area  \
# 0                         NaN                   NaN                   28.0
# 1                1.703132e+10          1.703132e+10                   32.0
# 2                1.703107e+10          1.703107e+10                    7.0
# 8                1.703198e+10          1.703184e+10                   76.0
# 15               1.703122e+10          1.703104e+10                   22.0
# ...                       ...                   ...                    ...
# 21638573                  NaN                   NaN                   30.0
# 21638574         1.703103e+10          1.703108e+10                    3.0
# 21638575         1.703133e+10          1.703133e+10                   33.0
# 21638576                  NaN                   NaN                   61.0
# 21638577                  NaN                   NaN                   14.0
#
#           Dropoff_Community_Area  ...  Payment_Type  Pickup_Centroid_Latitude  \
# 0                            8.0  ...          Cash                 41.874005
# 1                           32.0  ...          Cash                 41.870607
# 2                            7.0  ...          Cash                 41.928967
# 8                           34.0  ...          Cash                 41.979071
# 15                           4.0  ...          Cash                 41.921126
# ...                          ...  ...           ...                       ...
# 21638573                    14.0  ...          Cash                 41.839087
# 21638574                     8.0  ...   Credit Card                 41.972668
# 21638575                    33.0  ...          Cash                 41.859350
# 21638576                    22.0  ...          Cash                 41.809018
# 21638577                    14.0  ...          Cash                 41.968069
#
#           Pickup_Centroid_Longitude              Pickup_Centroid_Location  \
# 0                        -87.663518   POINT (-87.6635175498 41.874005383)
# 1                        -87.622173  POINT (-87.6221729369 41.8706073724)
# 2                        -87.656157  POINT (-87.6561568309 41.9289672664)
# 8                        -87.903040  POINT (-87.9030396611 41.9790708201)
# 15                       -87.699754  POINT (-87.6997544065 41.9211259143)
# ...                             ...                                   ...
# 21638573                 -87.714004   POINT (-87.714003807 41.8390869059)
# 21638574                 -87.663865  POINT (-87.6638654956 41.9726679555)
# 21638575                 -87.617358   POINT (-87.6173580061 41.859349715)
# 21638576                 -87.659167  POINT (-87.6591665992 41.8090182499)
# 21638577                 -87.721559      POINT (-87.7215590627 41.968069)
#
#          Dropoff_Centroid_Latitude  Dropoff_Centroid_Longitude  \
# 0                        41.899602                  -87.633308
# 1                        41.870607                  -87.622173
# 2                        41.929047                  -87.651311
# 8                        41.851018                  -87.635092
# 15                       41.966834                  -87.684018
# ...                            ...                         ...
# 21638573                 41.968069                  -87.721559
# 21638574                 41.892508                  -87.626215
# 21638575                 41.859350                  -87.617358
# 21638576                 41.922761                  -87.699155
# 21638577                 41.968069                  -87.721559
#
#                         Dropoff_Centroid__Location Community_Areas  \
# 0              POINT (-87.6333080367 41.899602111)            29.0
# 1             POINT (-87.6221729369 41.8706073724)            38.0
# 2             POINT (-87.6513108767 41.9290469366)            68.0
# 8             POINT (-87.6350918563 41.8510178239)            75.0
# 15            POINT (-87.6840183712 41.9668340674)            23.0
# ...                                            ...             ...
# 21638573          POINT (-87.7215590627 41.968069)            32.0
# 21638574      POINT (-87.6262149064 41.8925077809)            31.0
# 21638575       POINT (-87.6173580061 41.859349715)            34.0
# 21638576  POINT (-87.69915534320002 41.9227606205)            59.0
# 21638577          POINT (-87.7215590627 41.968069)            14.0
#
#           Original_Trip_Start_Timestamp  Original_Trip_End_Timestamp
# 0                   2013-01-01 00:00:00          2013-01-01 00:15:00
# 1                   2013-01-01 00:00:00          2013-01-01 00:00:00
# 2                   2013-01-01 00:00:00          2013-01-01 00:00:00
# 8                   2013-01-01 00:00:00          2013-01-01 00:30:00
# 15                  2013-01-01 00:00:00          2013-01-01 00:30:00
# ...                                 ...                          ...
# 21638573            2013-12-31 23:45:00          2014-01-01 00:30:00
# 21638574            2013-12-31 23:45:00          2014-01-01 00:00:00
# 21638575            2013-12-31 23:45:00          2014-01-01 00:00:00
# 21638576            2013-12-31 23:45:00          2014-01-01 00:15:00
# 21638577            2013-12-31 23:45:00          2014-01-01 00:00:00
#
# [10894156 rows x 24 columns]

# %%
df_chicago = df_chicago[(df_chicago['Trip_Start_Timestamp']>=datetime.datetime(year=2013, month=1, day=1, hour=0, minute=0, second=0))
         & (df_chicago['Trip_Start_Timestamp']<datetime.datetime(year=2014, month=1, day=1, hour=0, minute=0, second=0))]

# Reset index to new time interval of 2013
df_chicago.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## Creating additional features:

# %% [markdown]
# **FEATURE: `date_start`**

# %%
df_chicago['date_start'] = pd.to_datetime(df_chicago["Trip_Start_Timestamp"]).dt.date
# Out:
# /var/folders/rm/wg58__0d187f9f9gt07rpkw40000gn/T/ipykernel_3445/2266226602.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chicago['date_start'] = pd.to_datetime(df_chicago["Trip_Start_Timestamp"]).dt.date

# %% [markdown]
# **FEATURE: `dayOfWeek`**

# %%
df_chicago['dayOfWeek'] = pd.to_datetime(df_chicago["date_start"]).dt.day_name()
# Out:
# /var/folders/rm/wg58__0d187f9f9gt07rpkw40000gn/T/ipykernel_3445/1145573839.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chicago['dayOfWeek'] = pd.to_datetime(df_chicago["date_start"]).dt.day_name()

# %% [markdown]
# **FEATURE: `isHoliday`**

# %%
from datetime import date
import holidays

# Select country
us_holidays = holidays.US()
us_holidays
# Out:
# holidays.country_holidays('US')

# %%
df_chicago = df_chicago.assign(isHoliday=lambda x: x["date_start"].apply(lambda h: h in us_holidays))

# %% [markdown]
# **FEATURE: `season`**

# %%
# Returns the day of the year
def day_match(ts):
    return pd.Period(ts, freq='D').day_of_year

#seasons = {'spring': (start='2013-03-20', end='2013-06-20'),
 #          'summer': (start='2013/06/21', end='2013/09/22'),
 #          'autumn': (start='2013/09/23', end='2013/12/21'),
  #         'winter': rest}


# Create Array to map days to seasons (1 - 4)
seasons = ['winter' for i in range(0,78)]
seasons.extend('spring' for i in range(0,93))
seasons.extend('summer' for i in range(0,94))
seasons.extend('autumn' for i in range(0,90))
seasons.extend('winter' for i in range(0,10))

# Create dictionary for lambda expression
day_to_season = {}
for i in range(0,365):
    day_to_season[i+1] = seasons[i]
    
# Map start_date to day of the year (day_match) and afterwards map this to seasonnames (day_to_season)
df_chicago["season"] = df_chicago["date_start"].map(day_match).map(day_to_season)

# %%
print("In 2013 there were:\n", 
      "•", pd.Period("2013-03-19").day_of_year + (pd.Period("2013-12-31").day_of_year - pd.Period("2013/12/21").day_of_year), "winter days\n", 
      "•", pd.Period("2013/06/20").day_of_year - pd.Period("2013-03-19").day_of_year, "spring days\n",
      "•", pd.Period("2013/09/22").day_of_year - pd.Period("2013/06/20").day_of_year, "summer days\n",
      "•", pd.Period("2013/12/21").day_of_year - pd.Period("2013/09/22").day_of_year, "autumn days\n")
# Out:
# In 2013 there were:
#  • 88 winter days
#  • 93 spring days
#  • 94 summer days
#  • 90 autumn days

# %% [markdown]
# **FEATURE: `start_time_hourly`, `start_time_day` and `start_time_week`**

# %%
df_chicago['start_time_hourly'] = df_chicago['Trip_Start_Timestamp'].dt.hour

# %%
df_chicago['start_time_day'] = df_chicago['Trip_Start_Timestamp'].dt.day
df_chicago['start_time_week'] = df_chicago['Trip_Start_Timestamp'].dt.isocalendar()["week"]
df_chicago['start_time_month'] = df_chicago['Trip_Start_Timestamp'].dt.month

# %%
df_chicago
# Out:
#                                            Trip_ID  \
# 0         27ad87f629bf14fa3cb894daad514cdad4736f9c
# 1         7a3c9ab6e4da5c35448753e981bb73065a0c0319
# 2         9a9d9902dfa267b88400a22a2c9f0cf74384b372
# 3         235977a4b76994e0506b2c1775ad7b6a616140da
# 4         5e07d8d10a2314fb71214c71ca3f19beab79652d
# ...                                            ...
# 10893357  eda096d2b89a8b2b432642ec1e2a1a1fd72c4dd8
# 10893358  9bb135881fb88cd37521eddacd3003d6e6642e8f
# 10893359  e93c3a7ee7050521d22a6d513b65d94642813a4c
# 10893360  cf906408921ec94acfed42add2165ab0f52fe9b7
# 10893361  4996a695833096a0a412b77a918f5202554677bb
#
#                                                     Taxi_ID  \
# 0         4b38941e0745acdeefe630832a438a59fdaac78640f68a...
# 1         efce437d4bc2a79b12ac131e37789da8fe5e53f37d12c2...
# 2         1a1189d1e9f4f676bbeaf49903912684b94453576a234f...
# 3         99d30118c79bf4b5f037d2d26660bb2dbca0994fc503e2...
# 4         0826a2682f598bf0e39aa460479bc87757bd2fcb72c171...
# ...                                                     ...
# 10893357  0f1b65c1c73b1a8a687054ea0bb175edd243a5d065d7fa...
# 10893358  7b1ac8aace3932ce8b4302cc292a88c6d6f0446ea8134c...
# 10893359  9a03b73c5ab73cff888abb6ee2eb598352e4168671bd7c...
# 10893360  1e3120e8b2c9af9f006e47d546cc8cee6564dd40b15abe...
# 10893361  b56d49bc42507f35096478dd9613ed6aa7978739e34a99...
#
#          Trip_Start_Timestamp  Trip_End_Timestamp  Trip_Seconds  Trip_Miles  \
# 0         2013-01-01 00:00:00 2013-01-01 00:00:00         900.0         2.7
# 1         2013-01-01 00:00:00 2013-01-01 00:00:00          60.0         0.3
# 2         2013-01-01 00:00:00 2013-01-01 00:00:00         240.0         0.4
# 3         2013-01-01 00:00:00 2013-01-01 00:00:00        1440.0         1.2
# 4         2013-01-01 00:00:00 2013-01-01 00:00:00        1920.0         0.6
# ...                       ...                 ...           ...         ...
# 10893357  2013-12-31 23:00:00 2014-01-01 00:00:00         540.0         1.4
# 10893358  2013-12-31 23:00:00 2014-01-01 00:00:00        1860.0         5.9
# 10893359  2013-12-31 23:00:00 2014-01-01 00:00:00         720.0         2.0
# 10893360  2013-12-31 23:00:00 2013-12-31 23:00:00         660.0         3.5
# 10893361  2013-12-31 23:00:00 2014-01-01 00:00:00        1320.0         5.9
#
#           Pickup_Census_Tract  Dropoff_Census_Tract  Pickup_Community_Area  \
# 0                         NaN                   NaN                   28.0
# 1                1.703132e+10          1.703132e+10                   32.0
# 2                1.703107e+10          1.703107e+10                    7.0
# 3                1.703198e+10          1.703184e+10                   76.0
# 4                1.703122e+10          1.703104e+10                   22.0
# ...                       ...                   ...                    ...
# 10893357         1.703108e+10          1.703184e+10                    8.0
# 10893358         1.703108e+10          1.703106e+10                    8.0
# 10893359         1.703132e+10          1.703133e+10                   32.0
# 10893360         1.703108e+10          1.703184e+10                    8.0
# 10893361                  NaN                   NaN                   22.0
#
#           Dropoff_Community_Area  ...  Original_Trip_Start_Timestamp  \
# 0                            8.0  ...            2013-01-01 00:00:00
# 1                           32.0  ...            2013-01-01 00:00:00
# 2                            7.0  ...            2013-01-01 00:00:00
# 3                           34.0  ...            2013-01-01 00:00:00
# 4                            4.0  ...            2013-01-01 00:00:00
# ...                          ...  ...                            ...
# 10893357                     8.0  ...            2013-12-31 23:30:00
# 10893358                     6.0  ...            2013-12-31 23:30:00
# 10893359                    33.0  ...            2013-12-31 23:30:00
# 10893360                    33.0  ...            2013-12-31 23:30:00
# 10893361                    30.0  ...            2013-12-31 23:30:00
#
#           Original_Trip_End_Timestamp  date_start  dayOfWeek isHoliday  \
# 0                 2013-01-01 00:15:00  2013-01-01    Tuesday      True
# 1                 2013-01-01 00:00:00  2013-01-01    Tuesday      True
# 2                 2013-01-01 00:00:00  2013-01-01    Tuesday      True
# 3                 2013-01-01 00:30:00  2013-01-01    Tuesday      True
# 4                 2013-01-01 00:30:00  2013-01-01    Tuesday      True
# ...                               ...         ...        ...       ...
# 10893357          2013-12-31 23:45:00  2013-12-31    Tuesday     False
# 10893358          2014-01-01 00:00:00  2013-12-31    Tuesday     False
# 10893359          2013-12-31 23:45:00  2013-12-31    Tuesday     False
# 10893360          2013-12-31 23:30:00  2013-12-31    Tuesday     False
# 10893361          2013-12-31 23:45:00  2013-12-31    Tuesday     False
#
#           season  start_time_hourly start_time_day  start_time_week  \
# 0         winter                  0              1                1
# 1         winter                  0              1                1
# 2         winter                  0              1                1
# 3         winter                  0              1                1
# 4         winter                  0              1                1
# ...          ...                ...            ...              ...
# 10893357  winter                 23             31                1
# 10893358  winter                 23             31                1
# 10893359  winter                 23             31                1
# 10893360  winter                 23             31                1
# 10893361  winter                 23             31                1
#
#           start_time_month
# 0                        1
# 1                        1
# 2                        1
# 3                        1
# 4                        1
# ...                    ...
# 10893357                12
# 10893358                12
# 10893359                12
# 10893360                12
# 10893361                12
#
# [10893362 rows x 32 columns]

# %% [markdown]
# **FEATURE: `isRushhour`**

# %%
# Create feature isRushour
def isRushhour(time):
    if (time in [7,8,9,16,17,18,19]):
        return True
    else: 
        return False

df_chicago['isRushhour'] = df_chicago['start_time_hourly'].apply(lambda x:isRushhour(x))

# %% [markdown]
# **FEATURE: `velocity (miles/h)`**

# %%
df_chicago['velocity_(miles/h)'] = df_chicago['Trip_Miles']/(df_chicago['Trip_Seconds']/3600)

# %%
df_chicago.reset_index(drop = True, inplace=True)

# %%
#filtered_df = df_chicago[df_chicago['Trip_Start_Timestamp'] == '2013-03-10 00:00:00']
#filtered_df

# %% [markdown]
# ## Outlier Check in `df_chicago`

# %%
# histogram of the Trip_Seconds
n, bins, patches = plt.hist(df_chicago['Trip_Seconds'], 50, density=True, facecolor='g', alpha=0.75)


plt.xlabel('Tripduration in seconds')
plt.ylabel('Probability')
plt.grid(True)
plt.show()

# %%
# histogram of the Trip_Seconds with log
n, bins, patches = plt.hist(np.log(df_chicago['Trip_Seconds']), 50, density=True, facecolor='g', alpha=0.75)


plt.xlabel('Tripduration in seconds')
plt.ylabel('Probability')
plt.grid(True)
plt.show()

# %%
# histogram of the Trip_Miles
n, bins, patches = plt.hist(df_chicago['Trip_Miles'], 50, density=True, facecolor='g', alpha=0.75)


plt.xlabel('Tripdistance in miles')
plt.ylabel('Probability')
plt.grid(True)
plt.show()

# %%
# histogram of the Trip_Miles with log
n, bins, patches = plt.hist(np.log(df_chicago['Trip_Miles']), 50, density=True, facecolor='g', alpha=0.75)


plt.xlabel('Tripdistance in miles')
plt.ylabel('Probability')
plt.grid(True)
plt.show()

# %%
# histogram of the Fare
n, bins, patches = plt.hist(df_chicago['Fare'], 50, density=True, facecolor='g', alpha=0.75)


plt.xlabel('Fare in dollar')
plt.ylabel('Probability')
plt.grid(True)
plt.show()

# %%
# histogram of the Fare with log
n, bins, patches = plt.hist(np.log(df_chicago['Fare']), 50, density=True, facecolor='g', alpha=0.75)


plt.xlabel('Fare in dollar')
plt.ylabel('Probability')
plt.grid(True)
plt.show()

# %%
# histogram of the Fare
n, bins, patches = plt.hist(df_chicago['velocity_(miles/h)'], 50, density=True, facecolor='g', alpha=0.75)


plt.xlabel('velocity in (miles/h)')
plt.ylabel('Probability')
plt.grid(True)
plt.show()

# %%
# histogram of the Fare with log
n, bins, patches = plt.hist(np.log(df_chicago['velocity_(miles/h)']), 50, density=True, facecolor='g', alpha=0.75)


plt.xlabel('velocity in (miles/h)')
plt.ylabel('Probability')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Remove outliers

# %%
from scipy.stats import zscore

def remove_outliers(df,excluded_cols=None,zscore_threshold=2,verbose=False):
    
    outlier_count = 0
    df_numeric_view = df.select_dtypes(include="number")

    for col in df_numeric_view.columns:
        if excluded_cols and col in excluded_cols:
            continue
        df[f"{col}_zscore"] = np.around(np.abs(zscore(np.log(df[col]))), decimals=1)
        outlier = df[df[f"{col}_zscore"] > zscore_threshold]
        outlier_count += outlier.shape[0]
        df.drop(outlier.index, inplace=True)
        if verbose:
            print(
                f"--> {outlier.shape[0]} outlier detected and removed from {col} column using zscore"
            )
    df = df.loc[:, ~df.columns.str.contains("zscore")]

    print(f"Outlier detection completed. Number of removed outlier: {outlier_count}")

    return df.reset_index(drop=True)

# %%
df_chicago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10893362 entries, 0 to 10893361
# Data columns (total 34 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   Trip_ID                        object
#  1   Taxi_ID                        object
#  2   Trip_Start_Timestamp           datetime64[ns]
#  3   Trip_End_Timestamp             datetime64[ns]
#  4   Trip_Seconds                   float64
#  5   Trip_Miles                     float64
#  6   Pickup_Census_Tract            float64
#  7   Dropoff_Census_Tract           float64
#  8   Pickup_Community_Area          float64
#  9   Dropoff_Community_Area         float64
#  10  Fare                           float64
#  11  Tips                           float64
#  12  Tolls                          float64
#  13  Extras                         float64
#  14  Payment_Type                   object
#  15  Pickup_Centroid_Latitude       float64
#  16  Pickup_Centroid_Longitude      float64
#  17  Pickup_Centroid_Location       object
#  18  Dropoff_Centroid_Latitude      float64
#  19  Dropoff_Centroid_Longitude     float64
#  20  Dropoff_Centroid__Location     object
#  21  Community_Areas                float64
#  22  Original_Trip_Start_Timestamp  datetime64[ns]
#  23  Original_Trip_End_Timestamp    datetime64[ns]
#  24  date_start                     object
#  25  dayOfWeek                      object
#  26  isHoliday                      bool
#  27  season                         object
#  28  start_time_hourly              int64
#  29  start_time_day                 int64
#  30  start_time_week                UInt32
#  31  start_time_month               int64
#  32  isRushhour                     bool
#  33  velocity_(miles/h)             float64
# dtypes: UInt32(1), bool(2), datetime64[ns](4), float64(16), int64(3), object(8)
# memory usage: 2.6+ GB

# %%
df_chicago = remove_outliers(df_chicago,excluded_cols=['Trip_ID','Taxi_ID','Trip_Start_Timestamp',
                            'Trip_End_Timestamp','Pickup_Census_Tract','Dropoff_Census_Tract', 
                            'Pickup_Community_Area','Dropoff_Community_Area',
                            'Payment_Type','Company','Pickup_Centroid_Latitude','Pickup_Centroid_Longitude',
                            'Pickup_Centroid_Location','Dropoff_Centroid_Latitude','Dropoff_Centroid_Longitude',
                            'Dropoff_Centroid__Location','Community_Areas','Tips','Tolls','Extras','dayOfWeek',
                            'season','isRushhour','isHoliday','date_start','start_time_hourly','start_time_day',
                            'start_time_week','start_time_month']
                             ,zscore_threshold=2,verbose=True)
# Out:
# --> 547850 outlier detected and removed from Trip_Seconds column using zscore
# --> 165928 outlier detected and removed from Trip_Miles column using zscore
# --> 694967 outlier detected and removed from Fare column using zscore
# --> 510097 outlier detected and removed from velocity_(miles/h) column using zscore
# Outlier detection completed. Number of removed outlier: 1918842

# %%
df_chicago.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8974520 entries, 0 to 8974519
# Data columns (total 34 columns):
#  #   Column                         Non-Null Count    Dtype
# ---  ------                         --------------    -----
#  0   Trip_ID                        8974520 non-null  object
#  1   Taxi_ID                        8974520 non-null  object
#  2   Trip_Start_Timestamp           8974520 non-null  datetime64[ns]
#  3   Trip_End_Timestamp             8974520 non-null  datetime64[ns]
#  4   Trip_Seconds                   8974520 non-null  float64
#  5   Trip_Miles                     8974520 non-null  float64
#  6   Pickup_Census_Tract            6352657 non-null  float64
#  7   Dropoff_Census_Tract           6352657 non-null  float64
#  8   Pickup_Community_Area          8974520 non-null  float64
#  9   Dropoff_Community_Area         8974520 non-null  float64
#  10  Fare                           8974520 non-null  float64
#  11  Tips                           8974520 non-null  float64
#  12  Tolls                          8974520 non-null  float64
#  13  Extras                         8974520 non-null  float64
#  14  Payment_Type                   8974520 non-null  object
#  15  Pickup_Centroid_Latitude       8974520 non-null  float64
#  16  Pickup_Centroid_Longitude      8974520 non-null  float64
#  17  Pickup_Centroid_Location       8974520 non-null  object
#  18  Dropoff_Centroid_Latitude      8974520 non-null  float64
#  19  Dropoff_Centroid_Longitude     8974520 non-null  float64
#  20  Dropoff_Centroid__Location     8974520 non-null  object
#  21  Community_Areas                8974516 non-null  float64
#  22  Original_Trip_Start_Timestamp  8974520 non-null  datetime64[ns]
#  23  Original_Trip_End_Timestamp    8974520 non-null  datetime64[ns]
#  24  date_start                     8974520 non-null  object
#  25  dayOfWeek                      8974520 non-null  object
#  26  isHoliday                      8974520 non-null  bool
#  27  season                         8974520 non-null  object
#  28  start_time_hourly              8974520 non-null  int64
#  29  start_time_day                 8974520 non-null  int64
#  30  start_time_week                8974520 non-null  UInt32
#  31  start_time_month               8974520 non-null  int64
#  32  isRushhour                     8974520 non-null  bool
#  33  velocity_(miles/h)             8974520 non-null  float64
# dtypes: UInt32(1), bool(2), datetime64[ns](4), float64(16), int64(3), object(8)
# memory usage: 2.1+ GB

# %% [markdown]
# # 1.2 Weather data

# %%
#df_Weather = pd.read_csv("https://www.ncei.noaa.gov/access/services/data/v1?dataset=global-hourly&stations=72534014819&startDate=2013-01-01&endDate=2013-12-31&format=csv&units=metric")
#df_Weather.dropna(axis=1, how = 'any')

# %%
# import the weather datasets

df_hum = pd.read_csv("../data/weather/humidity.csv")
df_pres = pd.read_csv("../data/weather/pressure.csv")
df_temp = pd.read_csv("../data/weather/temperature.csv")
df_winddir = pd.read_csv("../data/weather/wind_direction.csv")
df_windsp = pd.read_csv("../data/weather/wind_speed.csv")
df_descr = pd.read_csv("../data/weather/weather_description.csv")

# %% [markdown]
# ## Cleaning the weather data sets:

# %%
# Change datatype of 'datetime' from object to datetime
df_hum['datetime'] = pd.to_datetime(df_hum['datetime'])
df_pres['datetime'] = pd.to_datetime(df_pres['datetime'])
df_temp['datetime'] = pd.to_datetime(df_temp['datetime'])
df_winddir['datetime'] = pd.to_datetime(df_hum['datetime'])
df_windsp['datetime'] = pd.to_datetime(df_hum['datetime'])
df_descr['datetime'] = pd.to_datetime(df_hum['datetime'])

# Since we only look at data from 2013, we can drop all rows from other years. 
df_hum = df_hum[(df_hum['datetime']>=datetime.datetime(year=2013, month=1, day=1, hour=0, minute=0, second=0))
         & (df_hum['datetime']<=datetime.datetime(year=2014, month=1, day=1, hour=0, minute=0, second=0))]
df_pres = df_pres[(df_pres['datetime']>=datetime.datetime(year=2013, month=1, day=1, hour=0, minute=0, second=0))
         & (df_pres['datetime']<=datetime.datetime(year=2014, month=1, day=1, hour=0, minute=0, second=0))]
df_temp = df_temp[(df_temp['datetime']>=datetime.datetime(year=2013, month=1, day=1, hour=0, minute=0, second=0))
         & (df_temp['datetime']<=datetime.datetime(year=2014, month=1, day=1, hour=0, minute=0, second=0))]
df_winddir = df_winddir[(df_winddir['datetime']>=datetime.datetime(year=2013, month=1, day=1, hour=0, minute=0, second=0))
         & (df_winddir['datetime']<=datetime.datetime(year=2014, month=1, day=1, hour=0, minute=0, second=0))]
df_windsp = df_windsp[(df_windsp['datetime']>=datetime.datetime(year=2013, month=1, day=1, hour=0, minute=0, second=0))
         & (df_windsp['datetime']<=datetime.datetime(year=2014, month=1, day=1, hour=0, minute=0, second=0))]
df_descr = df_descr[(df_descr['datetime']>=datetime.datetime(year=2013, month=1, day=1, hour=0, minute=0, second=0))
         & (df_descr['datetime']<=datetime.datetime(year=2014, month=1, day=1, hour=0, minute=0, second=0))]

# Reset index to new time intervall of 2013
df_hum.reset_index(drop=True, inplace=True)
df_pres.reset_index(drop=True, inplace=True)
df_temp.reset_index(drop=True, inplace=True)
df_winddir.reset_index(drop=True, inplace=True)
df_windsp.reset_index(drop=True, inplace=True)
df_descr.reset_index(drop=True, inplace=True)

# %%
df_hum = df_hum[['Chicago','datetime']]
df_pres = df_pres[['Chicago','datetime']]
df_temp = df_temp[['Chicago','datetime']]
df_winddir = df_winddir[['Chicago','datetime']]
df_windsp = df_windsp[['Chicago','datetime']]
df_descr = df_descr[['Chicago','datetime']]

# %%
# Test if there are duplicate rows in dfWeather
print("There are", len(df_hum)-len(df_hum.drop_duplicates()), "duplicate rows in df_hum.")
print("There are", len(df_pres)-len(df_pres.drop_duplicates()), "duplicate rows in df_pres.")
print("There are", len(df_temp)-len(df_temp.drop_duplicates()), "duplicate rows in df_temp.")
print("There are", len(df_winddir)-len(df_winddir.drop_duplicates()), "duplicate rows in df_winddir.")
print("There are", len(df_windsp)-len(df_windsp.drop_duplicates()), "duplicate rows in df_windsp.")
print("There are", len(df_descr)-len(df_descr.drop_duplicates()), "duplicate rows in df_descr.")
# Out:
# There are 0 duplicate rows in df_hum.
# There are 0 duplicate rows in df_pres.
# There are 0 duplicate rows in df_temp.
# There are 0 duplicate rows in df_winddir.
# There are 0 duplicate rows in df_windsp.
# There are 0 duplicate rows in df_descr.

# %%
# Test for datetime duplicates
print("There are", len(df_hum)-len(df_hum.drop_duplicates(subset='datetime')), "datetime duplicates in df_hum.")
print("There are", len(df_pres)-len(df_pres.drop_duplicates(subset='datetime')), "datetime duplicates in df_pres.")
print("There are", len(df_temp)-len(df_temp.drop_duplicates(subset='datetime')), "datetime duplicates in df_temp.")
print("There are", len(df_winddir)-len(df_winddir.drop_duplicates(subset='datetime')), "datetime duplicates in df_winddir.")
print("There are", len(df_windsp)-len(df_windsp.drop_duplicates(subset='datetime')), "datetime duplicates in df_windsp.")
print("There are", len(df_descr)-len(df_descr.drop_duplicates(subset='datetime')), "datetime duplicates in df_descr.")
# Out:
# There are 0 datetime duplicates in df_hum.
# There are 0 datetime duplicates in df_pres.
# There are 0 datetime duplicates in df_temp.
# There are 0 datetime duplicates in df_winddir.
# There are 0 datetime duplicates in df_windsp.
# There are 0 datetime duplicates in df_descr.

# %%
df_hum = df_hum[:-1]
df_pres = df_pres[:-1]
df_temp = df_temp[:-1]
df_winddir = df_winddir[:-1]
df_windsp = df_windsp[:-1]
df_descr = df_descr[:-1]

# %%
df_hum.rename(columns = {'Chicago':'humidity'},inplace=True)
df_pres.rename(columns = {'Chicago':'pressure'},inplace=True)
df_temp.rename(columns = {'Chicago':'temperature'},inplace=True)
df_winddir.rename(columns = {'Chicago':'wind_direction'},inplace=True)
df_windsp.rename(columns = {'Chicago':'wind_speed'},inplace=True)
df_descr.rename(columns = {'Chicago':'description'},inplace=True)

# %% [markdown]
# ## Creating dataframe `df_weather`

# %%
df_weather = pd.merge(df_pres, df_hum, on=["datetime"], how="left")
df_weather = pd.merge(df_weather, df_temp, on=["datetime"], how="left")
df_weather = pd.merge(df_weather, df_winddir, on=["datetime"], how="left")
df_weather = pd.merge(df_weather, df_windsp, on=["datetime"], how="left")
df_weather = pd.merge(df_weather, df_descr, on=["datetime"], how="left")

# %% [markdown]
# ### Edit features and interpolate:

# %%
df_weather['temperature'] = df_weather['temperature'] - 273.15

# %%
df_weather.rename(columns = {'temperature':'temperature_celsius'},inplace=True)

# %%
df_weather
# Out:
#       pressure            datetime  humidity  temperature_celsius  \
# 0       1024.0 2013-01-01 00:00:00       NaN                -0.19
# 1       1022.0 2013-01-01 01:00:00      64.0                 0.28
# 2       1022.0 2013-01-01 02:00:00      69.0                 0.33
# 3       1021.0 2013-01-01 03:00:00       NaN                 0.12
# 4       1021.0 2013-01-01 04:00:00      68.0                 0.04
# ...        ...                 ...       ...                  ...
# 8755    1026.0 2013-12-31 19:00:00      89.0               -11.27
# 8756    1026.0 2013-12-31 20:00:00      89.0               -10.60
# 8757    1026.0 2013-12-31 21:00:00      89.0               -10.98
# 8758    1026.0 2013-12-31 22:00:00      89.0               -11.24
# 8759    1023.0 2013-12-31 23:00:00      89.0               -11.00
#
#       wind_direction  wind_speed      description
# 0              200.0         4.0  overcast clouds
# 1              180.0         3.0    broken clouds
# 2              190.0         6.0  overcast clouds
# 3              190.0         7.0  overcast clouds
# 4              210.0         7.0    broken clouds
# ...              ...         ...              ...
# 8755           289.0         0.0    broken clouds
# 8756           269.0         0.0    broken clouds
# 8757           329.0         3.0       light snow
# 8758           241.0         1.0             snow
# 8759           217.0         1.0             mist
#
# [8760 rows x 7 columns]

# %%
print(f"Number of null values (NaN) in column 'description': {len(df_weather['description'])-len(df_weather['description'].dropna())}")
print(f"Number of null values (NaN) in column 'pressure': {len(df_weather['pressure'])-len(df_weather['pressure'].dropna())}")
print(f"Number of null values (NaN) in column 'humidity': {len(df_weather['humidity'])-len(df_weather['humidity'].dropna())}")
print(f"Number of null values (NaN) in column 'temperature_celsius': {len(df_weather['temperature_celsius'])-len(df_weather['temperature_celsius'].dropna())}")
print(f"Number of null values (NaN) in column 'wind_direction': {len(df_weather['wind_direction'])-len(df_weather['wind_direction'].dropna())}")
print(f"Number of null values (NaN) in column 'wind_speed': {len(df_weather['wind_speed'])-len(df_weather['wind_speed'].dropna())}")
# Out:
# Number of null values (NaN) in column 'description': 0
# Number of null values (NaN) in column 'pressure': 557
# Number of null values (NaN) in column 'humidity': 628
# Number of null values (NaN) in column 'temperature_celsius': 2
# Number of null values (NaN) in column 'wind_direction': 0
# Number of null values (NaN) in column 'wind_speed': 0

# %%
for column in ['temperature_celsius','humidity','pressure']:
    df_weather[column].interpolate(method='linear', limit_direction='both', inplace=True)

# %%
df_weather
# Out:
#       pressure            datetime  humidity  temperature_celsius  \
# 0       1024.0 2013-01-01 00:00:00      64.0                -0.19
# 1       1022.0 2013-01-01 01:00:00      64.0                 0.28
# 2       1022.0 2013-01-01 02:00:00      69.0                 0.33
# 3       1021.0 2013-01-01 03:00:00      68.5                 0.12
# 4       1021.0 2013-01-01 04:00:00      68.0                 0.04
# ...        ...                 ...       ...                  ...
# 8755    1026.0 2013-12-31 19:00:00      89.0               -11.27
# 8756    1026.0 2013-12-31 20:00:00      89.0               -10.60
# 8757    1026.0 2013-12-31 21:00:00      89.0               -10.98
# 8758    1026.0 2013-12-31 22:00:00      89.0               -11.24
# 8759    1023.0 2013-12-31 23:00:00      89.0               -11.00
#
#       wind_direction  wind_speed      description
# 0              200.0         4.0  overcast clouds
# 1              180.0         3.0    broken clouds
# 2              190.0         6.0  overcast clouds
# 3              190.0         7.0  overcast clouds
# 4              210.0         7.0    broken clouds
# ...              ...         ...              ...
# 8755           289.0         0.0    broken clouds
# 8756           269.0         0.0    broken clouds
# 8757           329.0         3.0       light snow
# 8758           241.0         1.0             snow
# 8759           217.0         1.0             mist
#
# [8760 rows x 7 columns]

# %% [markdown]
# ## Merging `df_chicago` and `df_weather` to `df_chicago`

# %%
df_chicago = pd.merge(df_chicago, df_weather, left_on="Trip_Start_Timestamp",right_on="datetime", how="left")
df_chicago
# Out:
#                                           Trip_ID  \
# 0        27ad87f629bf14fa3cb894daad514cdad4736f9c
# 1        9a9d9902dfa267b88400a22a2c9f0cf74384b372
# 2        5e07d8d10a2314fb71214c71ca3f19beab79652d
# 3        6deda34a1a498737aaa64734fa2c09a0bf335f18
# 4        faa2c909d0b88f3f54217135c6919a7fdd73a366
# ...                                           ...
# 8974515  eda096d2b89a8b2b432642ec1e2a1a1fd72c4dd8
# 8974516  9bb135881fb88cd37521eddacd3003d6e6642e8f
# 8974517  e93c3a7ee7050521d22a6d513b65d94642813a4c
# 8974518  cf906408921ec94acfed42add2165ab0f52fe9b7
# 8974519  4996a695833096a0a412b77a918f5202554677bb
#
#                                                    Taxi_ID  \
# 0        4b38941e0745acdeefe630832a438a59fdaac78640f68a...
# 1        1a1189d1e9f4f676bbeaf49903912684b94453576a234f...
# 2        0826a2682f598bf0e39aa460479bc87757bd2fcb72c171...
# 3        48c42d95f8331cbfbcab8a6d5299dbb654a041f3c2efff...
# 4        2e75c09511f6a1e2dee45f65888243ab9093f6c1558f10...
# ...                                                    ...
# 8974515  0f1b65c1c73b1a8a687054ea0bb175edd243a5d065d7fa...
# 8974516  7b1ac8aace3932ce8b4302cc292a88c6d6f0446ea8134c...
# 8974517  9a03b73c5ab73cff888abb6ee2eb598352e4168671bd7c...
# 8974518  1e3120e8b2c9af9f006e47d546cc8cee6564dd40b15abe...
# 8974519  b56d49bc42507f35096478dd9613ed6aa7978739e34a99...
#
#         Trip_Start_Timestamp  Trip_End_Timestamp  Trip_Seconds  Trip_Miles  \
# 0        2013-01-01 00:00:00 2013-01-01 00:00:00         900.0         2.7
# 1        2013-01-01 00:00:00 2013-01-01 00:00:00         240.0         0.4
# 2        2013-01-01 00:00:00 2013-01-01 00:00:00        1920.0         0.6
# 3        2013-01-01 00:00:00 2013-01-01 00:00:00         180.0         1.0
# 4        2013-01-01 00:00:00 2013-01-01 00:00:00         240.0         0.3
# ...                      ...                 ...           ...         ...
# 8974515  2013-12-31 23:00:00 2014-01-01 00:00:00         540.0         1.4
# 8974516  2013-12-31 23:00:00 2014-01-01 00:00:00        1860.0         5.9
# 8974517  2013-12-31 23:00:00 2014-01-01 00:00:00         720.0         2.0
# 8974518  2013-12-31 23:00:00 2013-12-31 23:00:00         660.0         3.5
# 8974519  2013-12-31 23:00:00 2014-01-01 00:00:00        1320.0         5.9
#
#          Pickup_Census_Tract  Dropoff_Census_Tract  Pickup_Community_Area  \
# 0                        NaN                   NaN                   28.0
# 1               1.703107e+10          1.703107e+10                    7.0
# 2               1.703122e+10          1.703104e+10                   22.0
# 3                        NaN                   NaN                   24.0
# 4               1.703128e+10          1.703132e+10                   28.0
# ...                      ...                   ...                    ...
# 8974515         1.703108e+10          1.703184e+10                    8.0
# 8974516         1.703108e+10          1.703106e+10                    8.0
# 8974517         1.703132e+10          1.703133e+10                   32.0
# 8974518         1.703108e+10          1.703184e+10                    8.0
# 8974519                  NaN                   NaN                   22.0
#
#          Dropoff_Community_Area  ...  start_time_month  isRushhour  \
# 0                           8.0  ...                 1       False
# 1                           7.0  ...                 1       False
# 2                           4.0  ...                 1       False
# 3                          24.0  ...                 1       False
# 4                          32.0  ...                 1       False
# ...                         ...  ...               ...         ...
# 8974515                     8.0  ...                12       False
# 8974516                     6.0  ...                12       False
# 8974517                    33.0  ...                12       False
# 8974518                    33.0  ...                12       False
# 8974519                    30.0  ...                12       False
#
#          velocity_(miles/h)  pressure            datetime  humidity  \
# 0                 10.800000    1024.0 2013-01-01 00:00:00      64.0
# 1                  6.000000    1024.0 2013-01-01 00:00:00      64.0
# 2                  1.125000    1024.0 2013-01-01 00:00:00      64.0
# 3                 20.000000    1024.0 2013-01-01 00:00:00      64.0
# 4                  4.500000    1024.0 2013-01-01 00:00:00      64.0
# ...                     ...       ...                 ...       ...
# 8974515            9.333333    1023.0 2013-12-31 23:00:00      89.0
# 8974516           11.419355    1023.0 2013-12-31 23:00:00      89.0
# 8974517           10.000000    1023.0 2013-12-31 23:00:00      89.0
# 8974518           19.090909    1023.0 2013-12-31 23:00:00      89.0
# 8974519           16.090909    1023.0 2013-12-31 23:00:00      89.0
#
#          temperature_celsius wind_direction  wind_speed      description
# 0                      -0.19          200.0         4.0  overcast clouds
# 1                      -0.19          200.0         4.0  overcast clouds
# 2                      -0.19          200.0         4.0  overcast clouds
# 3                      -0.19          200.0         4.0  overcast clouds
# 4                      -0.19          200.0         4.0  overcast clouds
# ...                      ...            ...         ...              ...
# 8974515               -11.00          217.0         1.0             mist
# 8974516               -11.00          217.0         1.0             mist
# 8974517               -11.00          217.0         1.0             mist
# 8974518               -11.00          217.0         1.0             mist
# 8974519               -11.00          217.0         1.0             mist
#
# [8974520 rows x 41 columns]

# %%
df_chicago.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8974520 entries, 0 to 8974519
# Data columns (total 41 columns):
#  #   Column                         Non-Null Count    Dtype
# ---  ------                         --------------    -----
#  0   Trip_ID                        8974520 non-null  object
#  1   Taxi_ID                        8974520 non-null  object
#  2   Trip_Start_Timestamp           8974520 non-null  datetime64[ns]
#  3   Trip_End_Timestamp             8974520 non-null  datetime64[ns]
#  4   Trip_Seconds                   8974520 non-null  float64
#  5   Trip_Miles                     8974520 non-null  float64
#  6   Pickup_Census_Tract            6352657 non-null  float64
#  7   Dropoff_Census_Tract           6352657 non-null  float64
#  8   Pickup_Community_Area          8974520 non-null  float64
#  9   Dropoff_Community_Area         8974520 non-null  float64
#  10  Fare                           8974520 non-null  float64
#  11  Tips                           8974520 non-null  float64
#  12  Tolls                          8974520 non-null  float64
#  13  Extras                         8974520 non-null  float64
#  14  Payment_Type                   8974520 non-null  object
#  15  Pickup_Centroid_Latitude       8974520 non-null  float64
#  16  Pickup_Centroid_Longitude      8974520 non-null  float64
#  17  Pickup_Centroid_Location       8974520 non-null  object
#  18  Dropoff_Centroid_Latitude      8974520 non-null  float64
#  19  Dropoff_Centroid_Longitude     8974520 non-null  float64
#  20  Dropoff_Centroid__Location     8974520 non-null  object
#  21  Community_Areas                8974516 non-null  float64
#  22  Original_Trip_Start_Timestamp  8974520 non-null  datetime64[ns]
#  23  Original_Trip_End_Timestamp    8974520 non-null  datetime64[ns]
#  24  date_start                     8974520 non-null  object
#  25  dayOfWeek                      8974520 non-null  object
#  26  isHoliday                      8974520 non-null  bool
#  27  season                         8974520 non-null  object
#  28  start_time_hourly              8974520 non-null  int64
#  29  start_time_day                 8974520 non-null  int64
#  30  start_time_week                8974520 non-null  UInt32
#  31  start_time_month               8974520 non-null  int64
#  32  isRushhour                     8974520 non-null  bool
#  33  velocity_(miles/h)             8974520 non-null  float64
#  34  pressure                       8974520 non-null  float64
#  35  datetime                       8974520 non-null  datetime64[ns]
#  36  humidity                       8974520 non-null  float64
#  37  temperature_celsius            8974520 non-null  float64
#  38  wind_direction                 8974520 non-null  float64
#  39  wind_speed                     8974520 non-null  float64
#  40  description                    8974520 non-null  object
# dtypes: UInt32(1), bool(2), datetime64[ns](5), float64(21), int64(3), object(9)
# memory usage: 2.7+ GB

# %% [markdown]
# # 1.3 Creating/Preparing Spatial data

# %% [markdown]
# We first start with understanding the given spatial information from `df_chicago`.
# For this we look at the columns `Pickup_Census_Tract`, `Pickup_Community_Area`, & `Pickup_Centroid_Latitude and Pickup_Centroid_Longitude`. We are only interested in the start location of the trip.
# According to https://data.cityofchicago.org/Transportation/Taxi-Trips/wrvz-psew#column-menu:
# - `Pickup_Census_Tract`: "The Census Tract where the trip began. For privacy, this Census Tract is not shown for some trips. This column often will be blank for locations outside Chicago."
# - `Pickup_Community_Area`: "The Community Area where the trip began. This column will be blank for locations outside Chicago."
# - `Pickup_Centroid_Latitude and Pickup_Centroid_Longitude`: "The latitude/longitude of the center of the pickup census tract or the community area if the census tract has been hidden for privacy. This columns often will be blank for locations outside Chicago."

# %%
df_chicago[["Pickup_Census_Tract"]].nunique()
# Out:
# Pickup_Census_Tract    365
# dtype: int64

# %%
df_chicago[["Pickup_Community_Area"]].nunique()
# Out:
# Pickup_Community_Area    77
# dtype: int64

# %%
df_chicago[["Pickup_Centroid_Latitude", "Pickup_Centroid_Longitude"]].nunique()
# Out:
# Pickup_Centroid_Latitude     442
# Pickup_Centroid_Longitude    442
# dtype: int64

# %%
unique_pairs = df_chicago[["Pickup_Centroid_Latitude", "Pickup_Centroid_Longitude"]].drop_duplicates().shape[0]
print("Pickup_Centroid_Latitude and Pickup_Centroid_Longitude form", unique_pairs, "unique pairs.")

if int(df_chicago[["Pickup_Census_Tract"]].nunique()) + int(df_chicago[["Pickup_Community_Area"]].nunique()) == unique_pairs:
    print("\nEvery Pickup_Census_Tract and Pickup_Community_Area are included in the pairs of Pickup_Centroid_Latitude & Pickup_Centroid_Longitude.\nIt is enough to use this values for the generation/preparation of spatial data!")
# Out:
# Pickup_Centroid_Latitude and Pickup_Centroid_Longitude form 442 unique pairs.
#
# Every Pickup_Census_Tract and Pickup_Community_Area are included in the pairs of Pickup_Centroid_Latitude & Pickup_Centroid_Longitude.
# It is enough to use this values for the generation/preparation of spatial data!

# %% [markdown]
# Now we want to **split the coordinates for `Pickup_Census_Tract` and `Pickup_Community_Area`**:

# %% [markdown]
# **Split the coordinates for `Pickup_Census_Tract`**:

# %%
# Get Every Census Tract
dfPickupCensusTract = df_chicago[["Pickup_Census_Tract","Pickup_Centroid_Latitude", "Pickup_Centroid_Longitude"]].drop_duplicates(subset=["Pickup_Census_Tract"])
# Drop the Null value
dfPickupCensusTract.dropna(inplace=True)
dfPickupCensusTract
# Out:
#          Pickup_Census_Tract  Pickup_Centroid_Latitude  \
# 1               1.703107e+10                 41.928967
# 2               1.703122e+10                 41.921126
# 4               1.703128e+10                 41.879255
# 6               1.703108e+10                 41.892073
# 7               1.703108e+10                 41.893216
# ...                      ...                       ...
# 8388783         1.703115e+10                 41.960518
# 8440395         1.703122e+10                 41.926156
# 8619102         1.703102e+10                 42.008541
# 8650376         1.703184e+10                 41.844661
# 8772321         1.703115e+10                 41.956779
#
#          Pickup_Centroid_Longitude
# 1                       -87.656157
# 2                       -87.699754
# 4                       -87.642649
# 6                       -87.628874
# 7                       -87.637844
# ...                            ...
# 8388783                 -87.762286
# 8440395                 -87.721565
# 8619102                 -87.694964
# 8650376                 -87.649072
# 8772321                 -87.781842
#
# [365 rows x 3 columns]

# %%
# Only keep coordinates for h3-Uber
dfPickupCensusTractCoordinates = dfPickupCensusTract.drop("Pickup_Census_Tract", axis=1)

# %% [markdown]
# **Split the coordinates for `Pickup_Community_Area`**:

# %%
# Get Every Community Area
dfPickupCommunityArea = df_chicago[["Pickup_Community_Area","Pickup_Centroid_Latitude", "Pickup_Centroid_Longitude"]].drop_duplicates(subset=["Pickup_Community_Area"])
# Drop potential Null value
dfPickupCommunityArea.dropna(inplace=True)
dfPickupCommunityArea
# Out:
#          Pickup_Community_Area  Pickup_Centroid_Latitude  \
# 0                         28.0                 41.874005
# 1                          7.0                 41.928967
# 2                         22.0                 41.921126
# 3                         24.0                 41.901207
# 6                          8.0                 41.892073
# ...                        ...                       ...
# 133401                    75.0                 41.689730
# 413032                    53.0                 41.673820
# 910190                    74.0                 41.694879
# 1997206                   54.0                 41.660136
# 2253608                   55.0                 41.663671
#
#          Pickup_Centroid_Longitude
# 0                       -87.663518
# 1                       -87.656157
# 2                       -87.699754
# 3                       -87.676356
# 6                       -87.628874
# ...                            ...
# 133401                  -87.669054
# 413032                  -87.635740
# 910190                  -87.713192
# 1997206                 -87.602848
# 2253608                 -87.540936
#
# [77 rows x 3 columns]

# %%
# Only keep coordinates for h3-Uber
dfPickupCommunityAreaCoordinates = dfPickupCommunityArea.drop("Pickup_Community_Area", axis=1)

# %% [markdown]
# Now we can start to discretize the city with the help of h3-Uber.

# %% [markdown]
# ## H3-Uber

# %% [markdown]
# **H3-Uber FEATURES: `h3_hex_id_high_res`, `h3_hex_id_medium_res` & `h3_hex_id_low_res`**

# %%
#pip install h3

# %%
#pip install folium

# %%
from h3 import h3
import folium

def visualize_hexagons(hexagons, color="red", folium_map=None):
    """
    hexagons is a list of hexcluster. Each hexcluster is a list of hexagons. 
    eg. [[hex1, hex2], [hex3, hex4]]
    """
    polylines = []
    lat = []
    lng = []
    for hex in hexagons:
        polygons = h3.h3_set_to_multi_polygon([hex], geo_json=False)
        # flatten polygons into loops.
        outlines = [loop for polygon in polygons for loop in polygon]
        polyline = [outline + [outline[0]] for outline in outlines][0]
        lat.extend(map(lambda v:v[0],polyline))
        lng.extend(map(lambda v:v[1],polyline))
        polylines.append(polyline)
    
    if folium_map is None:
        m = folium.Map(location=[sum(lat)/len(lat), sum(lng)/len(lng)], zoom_start=10, tiles='cartodbpositron')
    else:
        m = folium_map
    for polyline in polylines:
        my_PolyLine=folium.PolyLine(locations=polyline,weight=8,color=color)
        m.add_child(my_PolyLine)
    return m
    

def visualize_polygon(polyline, color):
    polyline.append(polyline[0])
    lat = [p[0] for p in polyline]
    lng = [p[1] for p in polyline]
    m = folium.Map(location=[sum(lat)/len(lat), sum(lng)/len(lng)], zoom_start=11, tiles='cartodbpositron')
    my_PolyLine=folium.PolyLine(locations=polyline,weight=8,color=color)
    m.add_child(my_PolyLine)
    return m

# %%
## Lists of coordinates to be covered by hexagons
#geoJsonPickupCensusTract = {'type': 'Polygon',
# 'coordinates': [dfPickupCensusTractCoordinates.values.tolist()] }
#geoJsonPickupCommunityArea = {'type': 'Polygon',
# 'coordinates': [dfPickupCommunityAreaCoordinates.values.tolist()] }
#
## Generate hexagons covering the included coordinates
#hexagonsPickupCensusTract = list(h3.polyfill(geoJsonPickupCensusTract, 8))
#hexagonsPickupCommunityArea = list(h3.polyfill(geoJsonPickupCommunityArea, 7))
#
## Generate Map
#m = visualize_hexagons(hexagonsPickupCensusTract, color="red")
#m = visualize_hexagons(hexagonsPickupCommunityArea, color="blue", folium_map=m)
#display(m)

# %%
#print("We have", len(hexagonsPickupCensusTract), "hexagons for Pickup_Census_Tract, but we have", int(df_chicago[["Pickup_Census_Tract"]].nunique()), "unique Pickup_Census_Tract in the data.")
#print("We have", len(hexagonsPickupCommunityArea), "hexagons for Pickup_Community_Area, but we have", int(df_chicago[["Pickup_Community_Area"]].nunique()), "unique Pickup_Community_Area in the data.")

# %% [markdown]
# **2nd Try**

# %%
import geopandas
import json
city_bounding = geopandas.read_file('../data/boundaries_city.geojson')
city_bounding_json_string = city_bounding.to_json()
city_bounding_json = json.loads(city_bounding_json_string)
city_bounding_poly = city_bounding_json["features"][0]

# %%
city_bounding.plot()
# Out:
# <Axes: >

# %%
city_bounding_poly["geometry"]["type"]
# Out:
# 'MultiPolygon'

# %%
# Create a GeoDataFrame from the MultiPolygon
gdf = geopandas.GeoDataFrame.from_features([city_bounding_poly])

# Explode the MultiPolygon into individual polygons
exploded_city_bounding_poly = gdf.explode()

exploded_city_bounding_poly
# Out:
# /var/folders/rm/wg58__0d187f9f9gt07rpkw40000gn/T/ipykernel_3445/3466830845.py:5: FutureWarning: Currently, index_parts defaults to True, but in the future, it will default to False to be consistent with Pandas. Use `index_parts=True` to keep the current behavior and True/False to silence the warning.
#   exploded_city_bounding_poly = gdf.explode()
#         name objectid     shape_area      shape_len  \
# 0 0  CHICAGO        1  6450276623.31  845282.931362
#   1  CHICAGO        1  6450276623.31  845282.931362
#
#                                               geometry
# 0 0  POLYGON ((-87.93514 42.00089, -87.93521 42.000...
#   1  POLYGON ((-87.93514 42.00089, -87.93509 42.000...

# %%
# Get both Polygons
cityBoundingPolygonSmall = {'type': 'Polygon', 'coordinates': city_bounding_poly["geometry"]["coordinates"][0]}
cityBoundingPolygonBig = {'type': 'Polygon', 'coordinates': city_bounding_poly["geometry"]["coordinates"][1]}

# %%
#from h3 import h3 
from shapely.geometry import shape

# Computing hexagons for a given polygon
H3_HEXAGON_HIGH_RESOLUTION = 8
H3_HEXAGON_MEDIUM_RESOLUTION = 7
H3_HEXAGON_LOW_RESOLUTION = 6

hexagonsChicagoSmallPartHighRes = h3.polyfill(cityBoundingPolygonSmall, res = H3_HEXAGON_HIGH_RESOLUTION, geo_json_conformant = True)
hexagonsChicagoBigPartHighRes = h3.polyfill(cityBoundingPolygonBig, res = H3_HEXAGON_HIGH_RESOLUTION, geo_json_conformant = True)
hexagonsChicagoBigPartMediumRes = h3.polyfill(cityBoundingPolygonBig, res = H3_HEXAGON_MEDIUM_RESOLUTION, geo_json_conformant = True)
hexagonsChicagoBigPartLowRes = h3.polyfill(cityBoundingPolygonBig, res = H3_HEXAGON_LOW_RESOLUTION, geo_json_conformant = True)

# %%
hexagonsChicagoSmallPartHighRes
# Out:
# set()

# %% [markdown]
# For H3_HEXAGON_RESOLUTION <= 8 is hexagonsChicagoSmallPart empty.
# Because of this we use only hexagonsChicagoBigPart in the following:

# %%
# Generate Map
#m = visualize_hexagons(hexagonsChicagoSmallPartHighRes, color="red") # We don't need this, because H3_HEXAGON_RESOLUTION <= 8
m = visualize_hexagons(hexagonsChicagoBigPartHighRes, color="orange")
m = visualize_hexagons(hexagonsChicagoBigPartMediumRes, color="darkgreen", folium_map=m)
m = visualize_hexagons(hexagonsChicagoBigPartLowRes, color="darkblue", folium_map=m)
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_226710ead8c6f97f242c83c0fe025354 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_226710ead8c6f97f242c83c0fe025354&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_226710ead8c6f97f242c83c0fe025354 = L.map(
#                 &quot;map_226710ead8c6f97f242c83c0fe025354&quot;,
#                 {
#                     center: [41.83803874125602, -87.68741716366897],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_40c33c84a279a4c66df45f6cb13f9127 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_226710ead8c6f97f242c83c0fe025354);
#
#
#             var poly_line_f562829c81d3f11010b23c365a4c5d21 = L.polyline(
#                 [[41.95437154130153, -87.75726335821103], [41.95255807573385, -87.76330561128579], [41.9479024886157, -87.76394151561487], [41.94506042197156, -87.75853632535431], [41.946873429406544, -87.75249479459073], [41.95152896156569, -87.75185773180843], [41.95437154130153, -87.75726335821103]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 8}
#             ).addTo(map_226710ead8c6f97f242c83c0fe025354);
#
#
#             var poly_line_7f0e5ed7c96cfa1f594a561f26d1f22e = L.polyline(
#                 [[42.01079074487129, -87.70312376574225], [42.00613186223475, -87.70376664532353], [42.00328517390982, -87.69835753434667], [42.00509685421868, -87.69230510875764], [42.00975568060331, -87.69166106799193], [42.012602882983764, -87.69707061396723], [42.01079074487129, -87.70312376574225]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 8}
#             ).addTo(map_226710ead8c6f97f242c83c0fe025354);
#
#
#             var poly_line_6d49357a8f3a6030a009121a32ad5720 = L.polyline(
#                 [[41.838825828016326, -87.65162899173], [41.83702102917968, -87.65766186153478], [41.832371954669924, -87.65830697187711], [41.8295277362744, -87.65292036477496], [41.83133207916433, -87.64688821724552], [41.83598109634402, -87.64624195457533], [41.838825828016326, -87.65162899173]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 8}
#             ).addTo(map_226710ead8c6f97f242c83c0fe025354);
#
#
#             var poly_line_abe645fda0fc18f81049be4f9c18e5ff = L.polyline(
#                 [[41.79261744145493, -87.68692444232192], [41.789775756188575, -87.68154108753254], [41.79158037148747, -87.67551566848557], [41.79622712801405, -87.67487288419056], [41.79906932601648, -87.68025666935289], [41.797264254703805, -87.68628280846943], [41.79261744145493, -87.68692444232192]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 8}
#             ).addTo(map_226710ead8c6f97f242c83c0fe025354);
#
#
#             var poly_line_ec4cde81d7b9b63ccc622b462463

# %%
print("We have", len(hexagonsChicagoBigPartHighRes), "hexagons for H3_HEXAGON_HIGH_RESOLUTION.")
print("We have", len(hexagonsChicagoBigPartMediumRes), "hexagons for H3_HEXAGON_MEDIUM_RESOLUTION.")
print("We have", len(hexagonsChicagoBigPartLowRes), "hexagons for H3_HEXAGON_LOW_RESOLUTION.")
# Out:
# We have 809 hexagons for H3_HEXAGON_HIGH_RESOLUTION.
# We have 116 hexagons for H3_HEXAGON_MEDIUM_RESOLUTION.
# We have 17 hexagons for H3_HEXAGON_LOW_RESOLUTION.

# %% [markdown]
# Now that we have decided analytically for an optimal selection of hexagon resolutions, we can apply the h3_hex_id's to our dataset:

# %% [markdown]
# **Create a dataframe with unique coordinates to shorten the runtime:**

# %%
unique_start_coordinates = df_chicago[["Pickup_Centroid_Latitude", "Pickup_Centroid_Longitude"]].drop_duplicates()

# %%
unique_start_coordinates
# Out:
#          Pickup_Centroid_Latitude  Pickup_Centroid_Longitude
# 0                       41.874005                 -87.663518
# 1                       41.928967                 -87.656157
# 2                       41.921126                 -87.699754
# 3                       41.901207                 -87.676356
# 4                       41.879255                 -87.642649
# ...                           ...                        ...
# 8388783                 41.960518                 -87.762286
# 8440395                 41.926156                 -87.721565
# 8619102                 42.008541                 -87.694964
# 8650376                 41.844661                 -87.649072
# 8772321                 41.956779                 -87.781842
#
# [442 rows x 2 columns]

# %%
# Get the hexagons
from shapely.geometry.polygon import Polygon

unique_start_coordinates["h3_hex_id_high_res"] = unique_start_coordinates.apply(lambda row: h3.geo_to_h3(row["Pickup_Centroid_Latitude"], row["Pickup_Centroid_Longitude"], H3_HEXAGON_HIGH_RESOLUTION) if (row['Pickup_Centroid_Latitude'] and row['Pickup_Centroid_Longitude']) else 0, axis=1)
unique_start_coordinates["h3_hex_id_medium_res"] = unique_start_coordinates.apply(lambda row: h3.geo_to_h3(row["Pickup_Centroid_Latitude"], row["Pickup_Centroid_Longitude"], H3_HEXAGON_MEDIUM_RESOLUTION) if (row['Pickup_Centroid_Latitude'] and row['Pickup_Centroid_Longitude']) else 0, axis=1)
unique_start_coordinates["h3_hex_id_low_res"] = unique_start_coordinates.apply(lambda row: h3.geo_to_h3(row["Pickup_Centroid_Latitude"], row["Pickup_Centroid_Longitude"], H3_HEXAGON_LOW_RESOLUTION) if (row['Pickup_Centroid_Latitude'] and row['Pickup_Centroid_Longitude']) else 0, axis=1)

unique_start_coordinates
# Out:
#          Pickup_Centroid_Latitude  Pickup_Centroid_Longitude  \
# 0                       41.874005                 -87.663518
# 1                       41.928967                 -87.656157
# 2                       41.921126                 -87.699754
# 3                       41.901207                 -87.676356
# 4                       41.879255                 -87.642649
# ...                           ...                        ...
# 8388783                 41.960518                 -87.762286
# 8440395                 41.926156                 -87.721565
# 8619102                 42.008541                 -87.694964
# 8650376                 41.844661                 -87.649072
# 8772321                 41.956779                 -87.781842
#
#         h3_hex_id_high_res h3_hex_id_medium_res h3_hex_id_low_res
# 0          882664ca91fffff      872664ca9ffffff   862664cafffffff
# 1          882664c12bfffff      872664c12ffffff   862664c17ffffff
# 2          882664ca11fffff      872664ca1ffffff   862664ca7ffffff
# 3          882664cac3fffff      872664cacffffff   862664cafffffff
# 4          882664c1adfffff      872664c1affffff   862664c1fffffff
# ...                    ...                  ...               ...
# 8388783    882664cb59fffff      872664d9bffffff   862664cb7ffffff
# 8440395    882664ca39fffff      872664ca3ffffff   862664ca7ffffff
# 8619102    882664d8edfffff      872664d8effffff   862664d8fffffff
# 8650376    882664cf47fffff      872664cf4ffffff   862664cf7ffffff
# 8772321    882664cb43fffff      872664cb5ffffff   862664cb7ffffff
#
# [442 rows x 5 columns]

# %%
# Merge the hexagoninformation into df_chicago
df_chicago = pd.merge(df_chicago, unique_start_coordinates, on=["Pickup_Centroid_Latitude", "Pickup_Centroid_Longitude"], how="left")
df_chicago
# Out:
#                                           Trip_ID  \
# 0        27ad87f629bf14fa3cb894daad514cdad4736f9c
# 1        9a9d9902dfa267b88400a22a2c9f0cf74384b372
# 2        5e07d8d10a2314fb71214c71ca3f19beab79652d
# 3        6deda34a1a498737aaa64734fa2c09a0bf335f18
# 4        faa2c909d0b88f3f54217135c6919a7fdd73a366
# ...                                           ...
# 8974515  eda096d2b89a8b2b432642ec1e2a1a1fd72c4dd8
# 8974516  9bb135881fb88cd37521eddacd3003d6e6642e8f
# 8974517  e93c3a7ee7050521d22a6d513b65d94642813a4c
# 8974518  cf906408921ec94acfed42add2165ab0f52fe9b7
# 8974519  4996a695833096a0a412b77a918f5202554677bb
#
#                                                    Taxi_ID  \
# 0        4b38941e0745acdeefe630832a438a59fdaac78640f68a...
# 1        1a1189d1e9f4f676bbeaf49903912684b94453576a234f...
# 2        0826a2682f598bf0e39aa460479bc87757bd2fcb72c171...
# 3        48c42d95f8331cbfbcab8a6d5299dbb654a041f3c2efff...
# 4        2e75c09511f6a1e2dee45f65888243ab9093f6c1558f10...
# ...                                                    ...
# 8974515  0f1b65c1c73b1a8a687054ea0bb175edd243a5d065d7fa...
# 8974516  7b1ac8aace3932ce8b4302cc292a88c6d6f0446ea8134c...
# 8974517  9a03b73c5ab73cff888abb6ee2eb598352e4168671bd7c...
# 8974518  1e3120e8b2c9af9f006e47d546cc8cee6564dd40b15abe...
# 8974519  b56d49bc42507f35096478dd9613ed6aa7978739e34a99...
#
#         Trip_Start_Timestamp  Trip_End_Timestamp  Trip_Seconds  Trip_Miles  \
# 0        2013-01-01 00:00:00 2013-01-01 00:00:00         900.0         2.7
# 1        2013-01-01 00:00:00 2013-01-01 00:00:00         240.0         0.4
# 2        2013-01-01 00:00:00 2013-01-01 00:00:00        1920.0         0.6
# 3        2013-01-01 00:00:00 2013-01-01 00:00:00         180.0         1.0
# 4        2013-01-01 00:00:00 2013-01-01 00:00:00         240.0         0.3
# ...                      ...                 ...           ...         ...
# 8974515  2013-12-31 23:00:00 2014-01-01 00:00:00         540.0         1.4
# 8974516  2013-12-31 23:00:00 2014-01-01 00:00:00        1860.0         5.9
# 8974517  2013-12-31 23:00:00 2014-01-01 00:00:00         720.0         2.0
# 8974518  2013-12-31 23:00:00 2013-12-31 23:00:00         660.0         3.5
# 8974519  2013-12-31 23:00:00 2014-01-01 00:00:00        1320.0         5.9
#
#          Pickup_Census_Tract  Dropoff_Census_Tract  Pickup_Community_Area  \
# 0                        NaN                   NaN                   28.0
# 1               1.703107e+10          1.703107e+10                    7.0
# 2               1.703122e+10          1.703104e+10                   22.0
# 3                        NaN                   NaN                   24.0
# 4               1.703128e+10          1.703132e+10                   28.0
# ...                      ...                   ...                    ...
# 8974515         1.703108e+10          1.703184e+10                    8.0
# 8974516         1.703108e+10          1.703106e+10                    8.0
# 8974517         1.703132e+10          1.703133e+10                   32.0
# 8974518         1.703108e+10          1.703184e+10                    8.0
# 8974519                  NaN                   NaN                   22.0
#
#          Dropoff_Community_Area  ...  pressure            datetime  humidity  \
# 0                           8.0  ...    1024.0 2013-01-01 00:00:00      64.0
# 1                           7.0  ...    1024.0 2013-01-01 00:00:00      64.0
# 2                           4.0  ...    1024.0 2013-01-01 00:00:00      64.0
# 3                          24.0  ...    1024.0 2013-01-01 00:00:00      64.0
# 4                          32.0  ...    1024.0 2013-01-01 00:00:00      64.0
# ...                         ...  ...       ...                 ...       ...
# 8974515                     8.0  ...    1023.0 2013-12-31 23:00:00      89.0
# 8974516                     6.0  ...    1023.0 2013-12-31 23:00:00      89.0
# 8974517                    33.0  ...    1023.0 2013-12-31 23:00:00      89.0
# 8974518                    33.0  ...    1023.0 2013-12-31 23:00:00      89.0
# 8974519                    30.0  ...    1023.0 2013-12-31 23:00:00      89.0
#
#          temperature_celsius wind_direction  wind_speed      description  \
# 0                      -0.19          200.0         4.0  overcast clouds
# 1                      -0.19          200.0         4.0  overcast clouds
# 2                      -0.19          200.0         4.0  overcast clouds
# 3                      -0.19          200.0         4.0  overcast clouds
# 4                      -0.19          200.0         4.0  overcast clouds
# ...                      ...            ...         ...              ...
# 8974515               -11.00          217.0         1.0             mist
# 8974516               -11.00          217.0         1.0             mist
# 8974517               -11.00          217.0         1.0             mist
# 8974518               -11.00          217.0         1.0             mist
# 8974519               -11.00          217.0         1.0             mist
#
#         h3_hex_id_high_res  h3_hex_id_medium_res  h3_hex_id_low_res
# 0          882664ca91fffff       872664ca9ffffff    862664cafffffff
# 1          882664c12bfffff       872664c12ffffff    862664c17ffffff
# 2          882664ca11fffff       872664ca1ffffff    862664ca7ffffff
# 3          882664cac3fffff       872664cacffffff    862664cafffffff
# 4          882664c1adfffff       872664c1affffff    862664c1fffffff
# ...                    ...                   ...                ...
# 8974515    882664c1e1fffff       872664c1effffff    862664c1fffffff
# 8974516    882664c1e1fffff       872664c1effffff    862664c1fffffff
# 8974517    882664c1e3fffff       872664c1effffff    862664c1fffffff
# 8974518    882664c1ebfffff       872664c1effffff    862664c1fffffff
# 8974519    882664ca11fffff       872664ca1ffffff    862664ca7ffffff
#
# [8974520 rows x 44 columns]

# %% [markdown]
# **?Refinement of FEATURE: `Pickup_Census_Tract`**

# %% [markdown]
# Potential export for building maps (for mapping values of `Pickup_Census_Tract` to coordinates)

# %%
dfPickupCensusTract
# Out:
#          Pickup_Census_Tract  Pickup_Centroid_Latitude  \
# 1               1.703107e+10                 41.928967
# 2               1.703122e+10                 41.921126
# 4               1.703128e+10                 41.879255
# 6               1.703108e+10                 41.892073
# 7               1.703108e+10                 41.893216
# ...                      ...                       ...
# 8388783         1.703115e+10                 41.960518
# 8440395         1.703122e+10                 41.926156
# 8619102         1.703102e+10                 42.008541
# 8650376         1.703184e+10                 41.844661
# 8772321         1.703115e+10                 41.956779
#
#          Pickup_Centroid_Longitude
# 1                       -87.656157
# 2                       -87.699754
# 4                       -87.642649
# 6                       -87.628874
# 7                       -87.637844
# ...                            ...
# 8388783                 -87.762286
# 8440395                 -87.721565
# 8619102                 -87.694964
# 8650376                 -87.649072
# 8772321                 -87.781842
#
# [365 rows x 3 columns]

# %% [markdown]
# **?Refinement of FEATURE: `Pickup_Community_Area`**

# %% [markdown]
# Potential export for building maps (for mapping values of `Pickup_Community_Area` to coordinates)

# %%
dfPickupCommunityArea
# Out:
#          Pickup_Community_Area  Pickup_Centroid_Latitude  \
# 0                         28.0                 41.874005
# 1                          7.0                 41.928967
# 2                         22.0                 41.921126
# 3                         24.0                 41.901207
# 6                          8.0                 41.892073
# ...                        ...                       ...
# 133401                    75.0                 41.689730
# 413032                    53.0                 41.673820
# 910190                    74.0                 41.694879
# 1997206                   54.0                 41.660136
# 2253608                   55.0                 41.663671
#
#          Pickup_Centroid_Longitude
# 0                       -87.663518
# 1                       -87.656157
# 2                       -87.699754
# 3                       -87.676356
# 6                       -87.628874
# ...                            ...
# 133401                  -87.669054
# 413032                  -87.635740
# 910190                  -87.713192
# 1997206                 -87.602848
# 2253608                 -87.540936
#
# [77 rows x 3 columns]

# %% [markdown]
# # 1.4 Creating different forecast periods

# %% [markdown]
# ## Creating dataframe `df_chicago_hourly`

# %%
# Create dataframe df_chicago_hourly
df_chicago_hourly = df_chicago[["date_start", "start_time_hourly"]]
df_chicago_hourly['numOfTaxisHourly'] = 0
df_chicago_hourly.head()
# Out:
# /var/folders/rm/wg58__0d187f9f9gt07rpkw40000gn/T/ipykernel_3445/4035832183.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chicago_hourly['numOfTaxisHourly'] = 0
#    date_start  start_time_hourly  numOfTaxisHourly
# 0  2013-01-01                  0                 0
# 1  2013-01-01                  0                 0
# 2  2013-01-01                  0                 0
# 3  2013-01-01                  0                 0
# 4  2013-01-01                  0                 0

# %%
# Calculate numOfRentedBikesHourly for each start_date & start_time_hourly
df_chicago_hourly = df_chicago_hourly.groupby(["date_start", "start_time_hourly"])['numOfTaxisHourly'].count().reset_index()
df_chicago_hourly
# Out:
#       date_start  start_time_hourly  numOfTaxisHourly
# 0     2013-01-01                  0              1218
# 1     2013-01-01                  1              2113
# 2     2013-01-01                  2              2459
# 3     2013-01-01                  3              2116
# 4     2013-01-01                  4              1550
# ...          ...                ...               ...
# 8755  2013-12-31                 19              3468
# 8756  2013-12-31                 20              4066
# 8757  2013-12-31                 21              4219
# 8758  2013-12-31                 22              4246
# 8759  2013-12-31                 23              3587
#
# [8760 rows x 3 columns]

# %%
df_chicago_hourly = pd.merge(df_chicago, df_chicago_hourly, on=["date_start", "start_time_hourly"], how="left")
df_chicago_hourly
# Out:
#                                           Trip_ID  \
# 0        27ad87f629bf14fa3cb894daad514cdad4736f9c
# 1        9a9d9902dfa267b88400a22a2c9f0cf74384b372
# 2        5e07d8d10a2314fb71214c71ca3f19beab79652d
# 3        6deda34a1a498737aaa64734fa2c09a0bf335f18
# 4        faa2c909d0b88f3f54217135c6919a7fdd73a366
# ...                                           ...
# 8974515  eda096d2b89a8b2b432642ec1e2a1a1fd72c4dd8
# 8974516  9bb135881fb88cd37521eddacd3003d6e6642e8f
# 8974517  e93c3a7ee7050521d22a6d513b65d94642813a4c
# 8974518  cf906408921ec94acfed42add2165ab0f52fe9b7
# 8974519  4996a695833096a0a412b77a918f5202554677bb
#
#                                                    Taxi_ID  \
# 0        4b38941e0745acdeefe630832a438a59fdaac78640f68a...
# 1        1a1189d1e9f4f676bbeaf49903912684b94453576a234f...
# 2        0826a2682f598bf0e39aa460479bc87757bd2fcb72c171...
# 3        48c42d95f8331cbfbcab8a6d5299dbb654a041f3c2efff...
# 4        2e75c09511f6a1e2dee45f65888243ab9093f6c1558f10...
# ...                                                    ...
# 8974515  0f1b65c1c73b1a8a687054ea0bb175edd243a5d065d7fa...
# 8974516  7b1ac8aace3932ce8b4302cc292a88c6d6f0446ea8134c...
# 8974517  9a03b73c5ab73cff888abb6ee2eb598352e4168671bd7c...
# 8974518  1e3120e8b2c9af9f006e47d546cc8cee6564dd40b15abe...
# 8974519  b56d49bc42507f35096478dd9613ed6aa7978739e34a99...
#
#         Trip_Start_Timestamp  Trip_End_Timestamp  Trip_Seconds  Trip_Miles  \
# 0        2013-01-01 00:00:00 2013-01-01 00:00:00         900.0         2.7
# 1        2013-01-01 00:00:00 2013-01-01 00:00:00         240.0         0.4
# 2        2013-01-01 00:00:00 2013-01-01 00:00:00        1920.0         0.6
# 3        2013-01-01 00:00:00 2013-01-01 00:00:00         180.0         1.0
# 4        2013-01-01 00:00:00 2013-01-01 00:00:00         240.0         0.3
# ...                      ...                 ...           ...         ...
# 8974515  2013-12-31 23:00:00 2014-01-01 00:00:00         540.0         1.4
# 8974516  2013-12-31 23:00:00 2014-01-01 00:00:00        1860.0         5.9
# 8974517  2013-12-31 23:00:00 2014-01-01 00:00:00         720.0         2.0
# 8974518  2013-12-31 23:00:00 2013-12-31 23:00:00         660.0         3.5
# 8974519  2013-12-31 23:00:00 2014-01-01 00:00:00        1320.0         5.9
#
#          Pickup_Census_Tract  Dropoff_Census_Tract  Pickup_Community_Area  \
# 0                        NaN                   NaN                   28.0
# 1               1.703107e+10          1.703107e+10                    7.0
# 2               1.703122e+10          1.703104e+10                   22.0
# 3                        NaN                   NaN                   24.0
# 4               1.703128e+10          1.703132e+10                   28.0
# ...                      ...                   ...                    ...
# 8974515         1.703108e+10          1.703184e+10                    8.0
# 8974516         1.703108e+10          1.703106e+10                    8.0
# 8974517         1.703132e+10          1.703133e+10                   32.0
# 8974518         1.703108e+10          1.703184e+10                    8.0
# 8974519                  NaN                   NaN                   22.0
#
#          Dropoff_Community_Area  ...            datetime  humidity  \
# 0                           8.0  ... 2013-01-01 00:00:00      64.0
# 1                           7.0  ... 2013-01-01 00:00:00      64.0
# 2                           4.0  ... 2013-01-01 00:00:00      64.0
# 3                          24.0  ... 2013-01-01 00:00:00      64.0
# 4                          32.0  ... 2013-01-01 00:00:00      64.0
# ...                         ...  ...                 ...       ...
# 8974515                     8.0  ... 2013-12-31 23:00:00      89.0
# 8974516                     6.0  ... 2013-12-31 23:00:00      89.0
# 8974517                    33.0  ... 2013-12-31 23:00:00      89.0
# 8974518                    33.0  ... 2013-12-31 23:00:00      89.0
# 8974519                    30.0  ... 2013-12-31 23:00:00      89.0
#
#          temperature_celsius  wind_direction wind_speed      description  \
# 0                      -0.19           200.0        4.0  overcast clouds
# 1                      -0.19           200.0        4.0  overcast clouds
# 2                      -0.19           200.0        4.0  overcast clouds
# 3                      -0.19           200.0        4.0  overcast clouds
# 4                      -0.19           200.0        4.0  overcast clouds
# ...                      ...             ...        ...              ...
# 8974515               -11.00           217.0        1.0             mist
# 8974516               -11.00           217.0        1.0             mist
# 8974517               -11.00           217.0        1.0             mist
# 8974518               -11.00           217.0        1.0             mist
# 8974519               -11.00           217.0        1.0             mist
#
#          h3_hex_id_high_res h3_hex_id_medium_res  h3_hex_id_low_res  \
# 0           882664ca91fffff      872664ca9ffffff    862664cafffffff
# 1           882664c12bfffff      872664c12ffffff    862664c17ffffff
# 2           882664ca11fffff      872664ca1ffffff    862664ca7ffffff
# 3           882664cac3fffff      872664cacffffff    862664cafffffff
# 4           882664c1adfffff      872664c1affffff    862664c1fffffff
# ...                     ...                  ...                ...
# 8974515     882664c1e1fffff      872664c1effffff    862664c1fffffff
# 8974516     882664c1e1fffff      872664c1effffff    862664c1fffffff
# 8974517     882664c1e3fffff      872664c1effffff    862664c1fffffff
# 8974518     882664c1ebfffff      872664c1effffff    862664c1fffffff
# 8974519     882664ca11fffff      872664ca1ffffff    862664ca7ffffff
#
#          numOfTaxisHourly
# 0                    1218
# 1                    1218
# 2                    1218
# 3                    1218
# 4                    1218
# ...                   ...
# 8974515              3587
# 8974516              3587
# 8974517              3587
# 8974518              3587
# 8974519              3587
#
# [8974520 rows x 45 columns]

# %%
df_chicago_hourly.drop(columns=['Trip_ID','Taxi_ID','Pickup_Census_Tract','Dropoff_Census_Tract', 
                            'Pickup_Community_Area','Dropoff_Community_Area',
                            'Payment_Type','Pickup_Centroid_Latitude','Pickup_Centroid_Longitude',
                            'Pickup_Centroid_Location','Dropoff_Centroid_Latitude','Dropoff_Centroid_Longitude',
                            'Dropoff_Centroid__Location','Community_Areas','Tips','Tolls','Extras',
                                'Trip_Miles','Trip_Seconds','Fare','velocity_(miles/h)']
                       , inplace = True)

# %%
df_chicago_hourly.drop_duplicates(subset=['Trip_Start_Timestamp'], inplace = True)

# %%
df_chicago_hourly = df_chicago_hourly.reset_index(drop = True)

# %%
df_chicago_hourly.drop(columns=['datetime'],inplace=True)

# %%
df_chicago_hourly.drop(columns=['Trip_Start_Timestamp'],inplace=True)

# %%
df_chicago_hourly.drop(columns=['Trip_End_Timestamp'],inplace=True)

# %%
df_chicago_hourly.drop(columns=['date_start'],inplace=True)

# %%
df_chicago_hourly
# Out:
#      Original_Trip_Start_Timestamp Original_Trip_End_Timestamp dayOfWeek  \
# 0              2013-01-01 00:00:00         2013-01-01 00:15:00   Tuesday
# 1              2013-01-01 00:45:00         2013-01-01 00:45:00   Tuesday
# 2              2013-01-01 01:45:00         2013-01-01 01:45:00   Tuesday
# 3              2013-01-01 02:45:00         2013-01-01 03:00:00   Tuesday
# 4              2013-01-01 03:45:00         2013-01-01 04:00:00   Tuesday
# ...                            ...                         ...       ...
# 8755           2013-12-31 18:45:00         2013-12-31 18:45:00   Tuesday
# 8756           2013-12-31 19:45:00         2013-12-31 19:45:00   Tuesday
# 8757           2013-12-31 20:45:00         2013-12-31 21:00:00   Tuesday
# 8758           2013-12-31 21:45:00         2013-12-31 22:00:00   Tuesday
# 8759           2013-12-31 22:45:00         2013-12-31 23:00:00   Tuesday
#
#       isHoliday  season  start_time_hourly  start_time_day  start_time_week  \
# 0          True  winter                  0               1                1
# 1          True  winter                  1               1                1
# 2          True  winter                  2               1                1
# 3          True  winter                  3               1                1
# 4          True  winter                  4               1                1
# ...         ...     ...                ...             ...              ...
# 8755      False  winter                 19              31                1
# 8756      False  winter                 20              31                1
# 8757      False  winter                 21              31                1
# 8758      False  winter                 22              31                1
# 8759      False  winter                 23              31                1
#
#       start_time_month  isRushhour  pressure  humidity  temperature_celsius  \
# 0                    1       False    1024.0      64.0                -0.19
# 1                    1       False    1022.0      64.0                 0.28
# 2                    1       False    1022.0      69.0                 0.33
# 3                    1       False    1021.0      68.5                 0.12
# 4                    1       False    1021.0      68.0                 0.04
# ...                ...         ...       ...       ...                  ...
# 8755                12        True    1026.0      89.0               -11.27
# 8756                12       False    1026.0      89.0               -10.60
# 8757                12       False    1026.0      89.0               -10.98
# 8758                12       False    1026.0      89.0               -11.24
# 8759                12       False    1023.0      89.0               -11.00
#
#       wind_direction  wind_speed      description h3_hex_id_high_res  \
# 0              200.0         4.0  overcast clouds    882664ca91fffff
# 1              180.0         3.0    broken clouds    882664c107fffff
# 2              190.0         6.0  overcast clouds    882664c1e3fffff
# 3              190.0         7.0  overcast clouds    882664c129fffff
# 4              210.0         7.0    broken clouds    882664c1b5fffff
# ...              ...         ...              ...                ...
# 8755           289.0         0.0    broken clouds    882664c1e1fffff
# 8756           269.0         0.0    broken clouds    882664c103fffff
# 8757           329.0         3.0       light snow    882664cf61fffff
# 8758           241.0         1.0             snow    882664c1edfffff
# 8759           217.0         1.0             mist    882664c1e3fffff
#
#      h3_hex_id_medium_res h3_hex_id_low_res  numOfTaxisHourly
# 0         872664ca9ffffff   862664cafffffff              1218
# 1         872664c13ffffff   862664c17ffffff              2113
# 2         872664c1effffff   862664c1fffffff              2459
# 3         872664c12ffffff   862664c17ffffff              2116
# 4         872664c1bffffff   862664c1fffffff              1550
# ...                   ...               ...               ...
# 8755      872664c1effffff   862664c1fffffff              3468
# 8756      872664c10ffffff   862664c17ffffff              4066
# 8757      872664cf6ffffff   862664cf7ffffff              4219
# 8758      872664c1effffff   862664c1fffffff              4246
# 8759      872664c1effffff   862664c1fffffff              3587
#
# [8760 rows x 20 columns]

# %% [markdown]
# ## Creating function for different periods

# %%
def period(df, period):
    
    num_groups = len(df) // period

    # create empty dataframe
    df_period = pd.DataFrame()

    # Iterate over the groups and sum the number of trips (storing in numOfTaxisHourly)
    for i in range(num_groups):
        group_start = i * period  # Starting index of the group
        group_end = (i + 1) * period  # Ending index of the group
        group_sum = df.iloc[group_start:group_end]['numOfTaxisHourly'].sum()  
        group_data = pd.DataFrame({'numOfTaxisHourly': [group_sum], 
                        'start_time_hourly': [df.iloc[group_start]['start_time_hourly']],
                        
                        'dayOfWeek': [df.iloc[group_start]['dayOfWeek']],
                        'isHoliday': [df.iloc[group_start]['isHoliday']],
                        'start_time_day': [df.iloc[group_start]['start_time_day']],
                        'start_time_week': [df.iloc[group_start]['start_time_week']],
                        'start_time_month': [df.iloc[group_start]['start_time_month']],
                        'start_time_day': [df.iloc[group_start]['start_time_day']],
                        'pressure': [df.iloc[group_start]['pressure']],
                        'humidity': [df.iloc[group_start]['humidity']],
                        'wind_direction': [df.iloc[group_start]['wind_direction']],
                        'wind_speed': [df.iloc[group_start]['wind_speed']],
                        'description': [df.iloc[group_start]['description']],
                        'temperature_celsius': [df.iloc[group_start]['temperature_celsius']]})  
        
        df_period = pd.concat([df_period, group_data], ignore_index=True)  
    
    # rename numOfTaxisHourly to numOfTaxis
    df_period.rename(columns = {'numOfTaxisHourly':'numOfTaxis'},inplace=True)
        
    return df_period

# %%
# for example for 2-hours
#df_2 =  period(df_chicago_hourly, 2)

# %% [markdown]
# # 1.5 Creating different spatial units

# %% [markdown]
# ## Creating function for different spatial units

# %% [markdown]
# Here we create functions for creating dataframes which contain temporal data grouped by the spatial data:

# %%
# col1: Pickup_Community_Area or hexagons

def spat_and_temp(df,col1,period):
    
    df = timeperiod(df,period)
    
    df['numOfTaxis_area'] = 0
    
    spa_temp = df.groupby(['start_stamp','date_start',col1])['numOfTaxis_area'].count()
    
    subset = df[['start_time_hourly','dayOfWeek','isHoliday','isRushhour','start_time_day','start_time_week',  
                 'start_time_month','pressure','humidity',  
                 'wind_direction','wind_speed','description', 'season',
        'temperature_celsius',"date_start",'start_stamp',col1]]
   
    spa_temp = pd.merge(spa_temp, subset, on=["date_start",'start_stamp',col1], how="left")
    spa_temp.drop_duplicates(subset=["date_start",'start_stamp',col1], inplace = True)
    spa_temp.reset_index(drop=True, inplace=True)
    
    return spa_temp

# %%
def timeperiod(df,period):

    df['start_stamp'] = ((df['start_time_hourly'] // period) * period).astype(int)
    
    return df

# %% [markdown]
# Create the following dataframes:
#
# - Hourly: Community Area, hexagon high resolution, hexagon medium resolution and hexagon low resolution
# - 2 hours: Community Area, hexagon high resolution, hexagon medium resolution and hexagon low resolution
# - 6 hours: Community Area, hexagon high resolution, hexagon medium resolution and hexagon low resolution
# - 24 hours: Community Area, hexagon high resolution, hexagon medium resolution and hexagon low resolution
#
#
# where:
#
# - Community Area is feature: `Pickup_Community_Area`
# - hexagon high resolution is feature: `h3_hex_id_high_res`
# - hexagon medium resolution is feature: `h3_hex_id_medium_res`
# - hexagon low resolution is feature: `h3_hex_id_low_res`
#
# Instead of using the census tract we are using the community areas. We do this, because due to privacy regulations of Chicago Data Portal we would otherwise have only a few data. Often the census tract of a trip isn't given, but the community area is. This arises for example, because if only two trips start in a specific census tract in a quarter hour interval, the census tract is not given for this trips, but instead the community area.
# This can be looked up on the following websites:
# - http://dev.cityofchicago.org/open%20data/data%20portal/2019/04/12/tnp-taxi-privacy.html
# - https://data.cityofchicago.org/Transportation/Taxi-Trips/wrvz-psew

# %% [markdown]
# #### Hourly:

# %%
df_h_comar = spat_and_temp(df_chicago,'Pickup_Community_Area',1)

# %%
df_h_hexlow = spat_and_temp(df_chicago,'h3_hex_id_low_res',1)

# %%
df_h_hexmed = spat_and_temp(df_chicago,'h3_hex_id_medium_res',1)

# %%
df_h_hexhig = spat_and_temp(df_chicago,'h3_hex_id_high_res',1)

# %% [markdown]
# #### 2 hours:

# %%
df_2h_comar = spat_and_temp(df_chicago,'Pickup_Community_Area',2)

# %%
df_2h_hexlow = spat_and_temp(df_chicago,'h3_hex_id_low_res',2)

# %%
df_2h_hexmed = spat_and_temp(df_chicago,'h3_hex_id_medium_res',2)

# %%
df_2h_hexhig = spat_and_temp(df_chicago,'h3_hex_id_high_res',2)

# %% [markdown]
# #### 6 hours:

# %%
df_6h_comar = spat_and_temp(df_chicago,'Pickup_Community_Area',6)

# %%
df_6h_hexlow = spat_and_temp(df_chicago,'h3_hex_id_low_res',6)

# %%
df_6h_hexmed = spat_and_temp(df_chicago,'h3_hex_id_medium_res',6)

# %%
df_6h_hexhig = spat_and_temp(df_chicago,'h3_hex_id_high_res',6)

# %% [markdown]
# #### 24 hours:

# %%
df_24h_comar = spat_and_temp(df_chicago,'Pickup_Community_Area',24)

# %%
df_24h_hexlow = spat_and_temp(df_chicago,'h3_hex_id_low_res',24)

# %%
df_24h_hexmed = spat_and_temp(df_chicago,'h3_hex_id_medium_res',24)

# %%
df_24h_hexhig = spat_and_temp(df_chicago,'h3_hex_id_high_res',24)

# %%
df_chicago.drop(columns=['start_stamp', 'numOfTaxis_area'],inplace = True) 
#otherwise the columns start_stamp and numOfTaxis_area are also in df_chicago

# %% [markdown]
# # 1.6 Export data sets

# %%
df_chicago.to_csv("../data/datasets/df_chicago.csv.zip",index = False, compression="zip")
df_chicago_hourly.to_csv("../data/datasets/df_chicago_hourly.csv",index = False)

df_h_comar.to_csv("../data/datasets/df_h_comar.csv",index = False)
df_h_hexlow.to_csv("../data/datasets/df_h_hexlow.csv",index = False)
df_h_hexmed.to_csv("../data/datasets/df_h_hexmed.csv",index = False)
df_h_hexhig.to_csv("../data/datasets/df_h_hexhig.csv",index = False)

df_2h_comar.to_csv("../data/datasets/df_2h_comar.csv",index = False)
df_2h_hexlow.to_csv("../data/datasets/df_2h_hexlow.csv",index = False)
df_2h_hexmed.to_csv("../data/datasets/df_2h_hexmed.csv",index = False)
df_2h_hexhig.to_csv("../data/datasets/df_2h_hexhig.csv",index = False)

df_6h_comar.to_csv("../data/datasets/df_6h_comar.csv",index = False)
df_6h_hexlow.to_csv("../data/datasets/df_6h_hexlow.csv",index = False)
df_6h_hexmed.to_csv("../data/datasets/df_6h_hexmed.csv",index = False)
df_6h_hexhig.to_csv("../data/datasets/df_6h_hexhig.csv",index = False)

df_24h_comar.to_csv("../data/datasets/df_24h_comar.csv",index = False)
df_24h_hexlow.to_csv("../data/datasets/df_24h_hexlow.csv",index = False)
df_24h_hexmed.to_csv("../data/datasets/df_24h_hexmed.csv",index = False)
df_24h_hexhig.to_csv("../data/datasets/df_24h_hexhig.csv",index = False)
